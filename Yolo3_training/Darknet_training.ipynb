# %% [markdown]
# <a href="https://colab.research.google.com/github/Peischlili/ComputerVision_WebScraper/blob/main/Darknet_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p>1. Connect to Google Drive account</p>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# <p>2. Install cdDNN</p>

# %%
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243

# %% [markdown]
# <p>3. Install Darknet in my VM</p>

# %%
# Change line.no 1 and 2 in ‘Makefile’, set the value to 1. This will enable Darknet to use GPU. commit and push the changes.
#clone the repo
# !git clone https://github.com/Peischlili/darknet.git
# Out:
# fatal: destination path 'darknet' already exists and is not an empty directory.

# %%
#cd into the darknet 
# %cd darknet

#Compile Darknet (make sure in Makefile that GPU and cuDNN are 1)
# !make
# Out:
# [Errno 20] Not a directory: 'darknet'
# /content/darknet
# chmod +x *.sh

# %% [markdown]
# <p>4. Upload config files and training data</p>

# %%
# download pretrained weights
# !cp -a /content/gdrive/My\ Drive/obj_cfg /content/darknet/

# %%
# load obj dataset (with annotations) in path
# !cp -a /content/gdrive/My\ Drive/obj /content/darknet/data/

# %% [markdown]
# <p>5. Training</p>

# %%
! ./darknet detector train /content/darknet/obj_cfg/obj.data /content/darknet/obj_cfg/yolo-obj.cfg /content/darknet/obj_cfg/darknet53.conv.74 -dont_show
#! ./darknet detector train obj_cfg/obj.data obj_cfg/yolo-obj.cfg. obj_cfg/darknet53.conv.74 -dont_show
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Loaded: 0.000056 seconds
#
#  2529: 0.892103, 0.633798 avg loss, 0.001000 rate, 0.515287 seconds, 40464 images
# Loaded: 0.000041 seconds
#
#  2530: 0.912907, 0.661709 avg loss, 0.001000 rate, 0.516276 seconds, 40480 images
# Resizing
# 352 x 352
#  try to allocate workspace = 13108225 * sizeof(float),  CUDA allocate done!
# Loaded: 0.000054 seconds
#
#  2531: 0.600548, 0.655593 avg loss, 0.001000 rate, 0.956307 seconds, 40496 images
# Loaded: 0.000045 seconds
#
#  2532: 0.614544, 0.651488 avg loss, 0.001000 rate, 1.001600 seconds, 40512 images
# Loaded: 0.000048 seconds
#
#  2533: 0.650213, 0.651361 avg loss, 0.001000 rate, 0.994698 seconds, 40528 images
# Loaded: 0.000046 seconds
#
#  2534: 0.953590, 0.681584 avg loss, 0.001000 rate, 0.991966 seconds, 40544 images
# Loaded: 0.000057 seconds
#
#  2535: 0.322455, 0.645671 avg loss, 0.001000 rate, 0.991816 seconds, 40560 images
# Loaded: 0.000067 seconds
# ...

# %%
# test training result
! ./darknet detector test obj_cfg/obj.data obj_cfg/yolo-obj.cfg backup/yolo-obj_last.weights
# Out:
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   256 x 256 x   3   ->   256 x 256 x  32 0.113 BF
#    1 conv     64  3 x 3 / 2   256 x 256 x  32   ->   128 x 128 x  64 0.604 BF
#    2 conv     32  1 x 1 / 1   128 x 128 x  64   ->   128 x 128 x  32 0.067 BF
#    3 conv     64  3 x 3 / 1   128 x 128 x  32   ->   128 x 128 x  64 0.604 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   128 x 128 x  64   ->    64 x  64 x 128 0.604 BF
#    6 conv     64  1 x 1 / 1    64 x  64 x 128   ->    64 x  64 x  64 0.067 BF
#    7 conv    128  3 x 3 / 1    64 x  64 x  64   ->    64 x  64 x 128 0.604 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1    64 x  64 x 128   ->    64 x  64 x  64 0.067 BF
#   10 conv    128  3 x 3 / 1    64 x  64 x  64   ->    64 x  64 x 128 0.604 BF
#   11 Shortcut Layer: 8
#   12 conv    256  3 x 3 / 2    64 x  64 x 128   ->    32 x  32 x 256 0.604 BF
# ...
