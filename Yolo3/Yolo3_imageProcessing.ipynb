# %% [markdown]
# <h1>Image pre-processing for object-detection model</h1>
# <p style="color:blue;font-size:18px;">Step 1: Read imges</p>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import random

# %%
# Defining global variable path that contains train / train_resized folders
image_folder = "/Users/peisch/code/WebScraper/ComputerVision_WebScraper/Images"

# Function to load folder into arrays and then it returns that same array
def loadImages(path):
    image_files = sorted([os.path.join(path, 'train', file)
         for file in os.listdir(path + "/train") if file.endswith('.jpg')])
    return image_files

# %%
# Check number of images in training set
len(loadImages(image_folder))
# Out:
# 836

# %% [markdown]
# <p style="color:blue;font-size:18px;">Step 2: Resize images</p>

# %%
# Display one image
def display_one(a, title1 = "Original"):
    plt.imshow(a), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.show()

# Display two images
def display(a, b, title1 = "Original", title2 = "Edited"):
    plt.subplot(121), plt.imshow(a), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(122), plt.imshow(b), plt.title(title2)
    plt.xticks([]), plt.yticks([])
    plt.show()

# %%
# Resize images into dimension determined and save resized images in new folder
# Generate a csv file including image information ie. origin weight/height, new width/height
# BE CAREFUL: we use "image_folder" global variable defined at the beginnning of the notebook

def resizing(data):
    
    # in the path given, create a folder for upcoming resized images if not existing
    os.chdir(image_folder)
    try:
        os.makedirs('train_resized')
    except FileExistsError:
        print("Directory 'train_resized' already exists. Resizing processing ... ")
        
    # Loop: for each image in the folder, store the 1/image, 2/origin size, 3/filename as imageId
    
    # create a dataframe to store information with determined typing for each column
    dtypes = np.dtype([
          ('imageId', str),
          ('origin_width', int),
          ('origin_height', int),
          ('new_width', int),
          ('new_height', int),
          ])
    empty_data = np.empty(0, dtype=dtypes)
    df = pd.DataFrame(empty_data)
    img_list = []
    
    # set working directory (folder) to store processed images
    working_dir = image_folder + "/train_resized/"
    os.chdir(working_dir)
        
    # setting dimemsion of the resized image and update count for processed images
    count:int = 0
    height:int = 256
    width:int = 256
    dim = (width, height) # dimension is a tuple
    res_img = []
    
    # for each absolute path in the list 'data':
    # 1/read image; 2/get its origin image and imageID; 3/update image list;
    # 4/store info in dataframe; 5/store resized image in created "train_resized" folder
    
    for imgStr in data:
        img = [cv2.imread(imgStr, cv2.IMREAD_UNCHANGED)]
        origin_size = img[0].shape # shape of each image is a tuple of (height, weight, channel)
        origin_width = origin_size[1]
        origin_height = origin_size[0]
        imageId = imgStr.rstrip('.jpg').lstrip(image_folder + "/train/")
        img_list[len(img_list):] = [imageId] # equiv to "append" to a list
        #print(f"Original size : {img[0].shape} ; Image ID: {imageId}")
        
        # store info as a new row in the dataframe created above
        col_names = ['imageId', 'origin_width', 'origin_height', 'new_width', 'new_height']
        new_row = pd.DataFrame([[str(imageId), origin_width, origin_height, width, height]], columns = col_names)
        df = df.append(new_row)
        
        # resize image and store as .jpg in created folder
        res = cv2.resize(img[0], dim, interpolation=cv2.INTER_LINEAR)
        res_img.append(res)
        count = count + 1
        filename:str = imageId + ".jpg"
        cv2.imwrite(filename, res)
            
    # Checking the size after processing
    print("Resized image :", res_img[-1].shape)
    
    # Visualizing one of the images in the array
    example_image = res_img[-1]
    display_one(example_image)
    
    # Delete duplicates of the df
    # Save dataframe into a CSV file (write or override .csv file)
    df = df.drop_duplicates()
    df.to_csv('imageTable.csv', index = False)
            
    print(f"Resizing finished. \n [ {count} ] image(s) resized and saved in directory: {working_dir} ")  
    return img_list

# %% [markdown]
# <p style="color:blue;font-size:18px;">Step 3: Recalculate image annotations</p>

# %%
def get_label(images):
    # set working dir to the resized folder 
    working_dir = image_folder + '/train_resized'
    os.chdir(working_dir)
    # load csv file containing image information
    df_img = pd.read_csv('imageTable.csv')
    df_img = df_img.set_index('imageId')
    
    dtypes = np.dtype([
          ('class', str),
          ('origin_xmin', int),
          ('origin_ymin', int),
          ('origin_xmax', int),
          ('origin_ymax', int),
          ('imageId', str)
          ])
    #empty_data = np.empty(0, dtype=dtypes)
    #df = pd.DataFrame(empty_data)
    
    image_buffer:str = ""
    
    for img in images:
        os.chdir(image_folder + '/train/Label')
        image_buffer = img
        filename = img + '.txt'
        # open origin .txt file and get information
        f = open(filename,"r")
        content = f.read()
        # parse content and store in info list
        annotations = content.lstrip().rstrip().split('\n')
        annot_str:str = ""
            
        # each_annot is a string with shape: 'Dress', '483.84', '228.734651', '691.2', '683.0'
        for each_annot in annotations:
            # load info about the origin image stored in csv file
            line = df_img.loc[img]
            o_w = line['origin_width']
            o_h = line['origin_height']
            n_w = line['new_width']
            n_h = line['new_height']
            each_annot = each_annot.replace(",\n", ", ")
            # replace "Dress" by its class number (zero)
            each_annot = each_annot.replace("Dress", "0")
            # now access to information contained by dress and redo the annotation for Yolo3 model
            # annotation for Yolo3: x(centre), y(center), width, height (with all in range [0, 1])
            dress:list = each_annot.split(" ") #list
            xmin = dress[1]
            ymin = dress[2]
            xmax = dress[3]
            ymax = dress[4]
            x = (float(xmin) + float(xmax))/2/o_w
            y = (float(ymin) + float(ymax))/2/o_h
            box_w = (float(xmax)-float(xmin))/o_w
            box_h = (float(ymax)-float(ymin))/o_h
            # the string has the right form for yolo annotation
            each_box:str = f"0 {x} {y} {box_w} {box_h}"
            annot_str:str = each_box + "\n" + annot_str
        annot_str = annot_str.rstrip()
        f.close
        
        # create a folder to store .txt files named 'new_labels'
        os.chdir(image_folder)
        try: os.mkdir('new_labels') 
        except: FileExistsError
        os.chdir(image_folder + '/new_labels')    
        new_file = open(filename,"w")
        n = new_file.write(annot_str)
        new_file.close()
        
    print(f"New annotation .txt files had been saved in directory: {image_folder}/new_labels ")

# %% [markdown]
# <p style="color:blue;font-size:18px;">Step 4: Create train and test path files</p>

# %%
# this function is to produce train.txt and test.txt files used in Yolo3 training
def create_txt_file(img_list):
    # full path list
    store_list = []
    for i in range(len(img_list)): 
        img_path = f"data/obj/{img_list[i]}.jpg"
        store_list.append(img_path)
    
    # randomise train set and test set
    img_nb = len(store_list)
    # parameter of the dataset separation ratio
    train_r = 0.8
    test_r = 0.2
    train_nb = round(img_nb * train_r)
    test_nb = img_nb - train_nb
    
    train_index = random.sample(range(img_nb), k = train_nb)
    # train path list
    train_list = []
    for i in train_index : 
        path = store_list[i]
        train_list.append(path)
    # test path list
    test_list = list(set(store_list) - set(train_list))
    print(f"Set separation done. Train set size: {len(train_list)}. Test set size: {len(test_list)}.")
    
    # save those lists into .txt files
    # create a folder to store .txt files named 'train_test_file'
    os.chdir(image_folder)
    try: os.mkdir('train_test_path') 
    except: FileExistsError
    os.chdir(image_folder + '/train_test_path')
    
    # create and save train.txt
    train_str = '\n'.join(train_list)
    file1 = open("train.txt", "w")
    n = file1.write(train_str)
    file1.close()
    print(f"train.txt file had been saved in directory: {image_folder}/train_test_path")
    
     # create and save test.txt
    test_str = '\n'.join(test_list)
    file2 = open("test.txt", "w")
    n = file2.write(test_str)
    file2.close()
    print(f"test.txt file had been saved in directory: {image_folder}/train_test_path")
    
    return store_list

# %% [markdown]
# <p style="color:blue;font-size:18px;">Execute sequential functions</p>

# %%
# Load data with given image folder path
dataset = loadImages(image_folder)

# Call the resizing function over data and save imageTable.csv
images = resizing(dataset)

# Process all label .txt files and save new .txt files in new_labels folder
get_label(images)

# Create path file for Yolo3 training
create_txt_file(images)
# Out:
# Resized image : (256, 256, 3)
# Resizing finished.
#  [ 836 ] image(s) resized and saved in directory: /Users/peisch/code/WebScraper/ComputerVision_WebScraper/Images/train_resized/
# New annotation .txt files had been saved in directory: /Users/peisch/code/WebScraper/ComputerVision_WebScraper/Images/new_labels
# Set separation done. Train set size: 669. Test set size: 167.
# train.txt file had been saved in directory: /Users/peisch/code/WebScraper/ComputerVision_WebScraper/Images/train_test_path
# test.txt file had been saved in directory: /Users/peisch/code/WebScraper/ComputerVision_WebScraper/Images/train_test_path
# ['data/obj/0000a1229c025d92.jpg',
#  'data/obj/0000b366aaf9672a.jpg',
#  'data/obj/00015dd91eb8e269.jpg',
#  'data/obj/000161230ca61936.jpg',
#  'data/obj/0002e0d9c42c2d60.jpg',
#  'data/obj/0002f5f227b0c2dc.jpg',
#  'data/obj/000339b87214a9c0.jpg',
#  'data/obj/0003dd5ed2b12811.jpg',
#  'data/obj/00043d188e7dec73.jpg',
#  'data/obj/000506542b3a9dd7.jpg',
#  'data/obj/0005080de8a33baa.jpg',
#  'data/obj/00052866345c0f72.jpg',
#  'data/obj/00056e3e7311ae2f.jpg',
#  'data/obj/0005f61b5f58c6ea.jpg',
#  'data/obj/0006072c8deef302.jpg',
#  'data/obj/00074f5faa995145.jpg',
#  'data/obj/00078d9de5011c3b.jpg',
#  'data/obj/0007a2e7a0558219.jpg',
#  'data/obj/0008547f1438ad1b.jpg',
#  'data/obj/00086b5a9a890446.jpg',
#  'data/obj/0008e1762a3da733.jpg',
#  'data/obj/000902770c2eae71.jpg',
#  'data/obj/0009261893325aa4.jpg',
#  'data/obj/00096c04dd2f62be.jpg',
#  'data/obj/0009d5f065682505.jpg',
#  'data/obj/0009d75b4c44e97c.jpg',
#  'data/obj/000ad0ecfb21ee63.jpg',
#  'data/obj/000b09d5d3fc821f.jpg',
#  'data/obj/000b8d80f7386698.jpg',
#  'data/obj/000b93644609911f.jpg',
#  'data/obj/000be05994bb5646.jpg',
#  'data/obj/000bfd340e3fe9ee.jpg',
#  'data/obj/000c43ac071d4ef8.jpg',
#  'data/obj/000d1a3a85de01ff.jpg',
#  'data/obj/000db364e6b977b9.jpg',
#  'data/obj/000e57aea51c9ea1.jpg',
#  'data/obj/000f80ac9b064fb6.jpg',
#  'data/obj/000fb04680ed7303.jpg',
#  'data/obj/0012411efe69efdb.jpg',
#  'data/obj/00128c134b172e6b.jpg',
#  'data/obj/0012c270e7a0d8e9.jpg',
#  'data/obj/00136a5777964e96.jpg',
#  'data/obj/00145feb6b15d975.jpg',
#  'data/obj/0014623c4ffa263f.jpg',
#  'data/obj/0014c3b48667efde.jpg',
#  'data/obj/0014d57c8ab3b2bc.jpg',
#  'data/obj/0015f5bc7fb8c422.jpg',
#  'data/obj/0016128987f8b86a.jpg',
#  'data/obj/0017a66b261aea04.jpg',
#  'data/obj/0017b3722e2579fe.jpg',
#  'data/obj/00183288ac75678a.jpg',
#  'data/obj/0018349c11b0dab9.jpg',
#  'data/obj/00184794d98eb454.jpg',
#  'data/obj/00186377f046098e.jpg',
#  'data/obj/0018b51b5de7af57.jpg',
#  'data/obj/00195c754cb0c73c.jpg',
#  'data/obj/0019c91cf778e003.jpg',
#  'data/obj/001a5f47e53e2f1b.jpg',
#  'data/obj/001a63f2bff24c20.jpg',
#  'data/obj/001a74e4675b1c9d.jpg',
#  'data/obj/001c89242ad9886e.jpg',
#  'data/obj/001ce5768e26d356.jpg',
#  'data/obj/001d5cdabe1cadb1.jpg',
#  'data/obj/001da8aeda193c79.jpg',
#  'data/obj/001df2c6cdba97b5.jpg',
#  'data/obj/001fb08c97bbdf6b.jpg',
#  'data/obj/0020b51e9896a061.jpg',
#  'data/obj/0020dab1cc6057ee.jpg',
#  'data/obj/0021959ee71f584c.jpg',
#  'data/obj/0021b16f6d1ef4ba.jpg',
#  'data/obj/0021e144437e8cee.jpg',
#  'data/obj/0022939df6108a93.jpg',
#  'data/obj/002299485887aae4.jpg',
#  'data/obj/0022f10af6d46840.jpg',
#  'data/obj/0022f3f909e77d8d.jpg',
#  'data/obj/0023036021bfa0ff.jpg',
#  'data/obj/0024272d034d0c98.jpg',
#  'data/obj/00251651409e8d12.jpg',
#  'data/obj/002790511b9920a5.jpg',
#  'data/obj/0027da661df176be.jpg',
#  'data/obj/00287d28172d1b20.jpg',
#  'data/obj/0028d8db5f3295dd.jpg',
#  'data/obj/0029b9ec6c822715.jpg',
#  'data/obj/002a1bb5f7533c39.jpg',
#  'data/obj/002a79cadd1ddfbe.jpg',
#  'data/obj/002ac7987dd7968f.jpg',
#  'data/obj/002b487e4c1d73e3.jpg',
#  'data/obj/002baf407afe7922.jpg',
#  'data/obj/002c4e3ca35ff9f2.jpg',
#  'data/obj/002d1aee4cfa12eb.jpg',
#  'data/obj/002dfe804d905159.jpg',
#  'data/obj/002e7ffc5cd92c44.jpg',
#  'data/obj/002f670b2f4c063c.jpg',
#  'data/obj/003074cbd3573914.jpg',
#  'data/obj/003099cf83a911bc.jpg',
#  'data/obj/00314fbbd638478a.jpg',
#  'data/obj/0031779d642878f4.jpg',
#  'data/obj/0031e7f17e9b1499.jpg',
#  'data/obj/003235453658d9f8.jpg',
#  'data/obj/0032648f3e8e5a72.jpg',
#  'data/obj/00339b611279e839.jpg',
#  'data/obj/00342dbcfa931395.jpg',
#  'data/obj/00344373ad800747.jpg',
#  'data/obj/00355ad38c86bb7d.jpg',
#  'data/obj/0035d88cc012fc4d.jpg',
#  'data/obj/0036545353017235.jpg',
#  'data/obj/0036b6ccf54b4afc.jpg',
#  'data/obj/00371264fa5a0f7c.jpg',
#  'data/obj/00375bd54c79dfb6.jpg',
#  'data/obj/003875367ddaa387.jpg',
#  'data/obj/003b21e6fdfc5a40.jpg',
#  'data/obj/003b7be9b72524b1.jpg',
#  'data/obj/003b9985e921de17.jpg',
#  'data/obj/003c5e88e00d0762.jpg',
#  'data/obj/003d36bec4be03c9.jpg',
#  'data/obj/003dcb16d493f3eb.jpg',
#  'data/obj/003dfdc6e30fa4a8.jpg',
#  'data/obj/003e278cb21f8a0d.jpg',
#  'data/obj/003f4f054b720c04.jpg',
#  'data/obj/003ff77db3fed521.jpg',
#  'data/obj/00406920c02a11c0.jpg',
#  'data/obj/0040960751f5d31c.jpg',
#  'data/obj/004136830be16772.jpg',
#  'data/obj/004169d70f9359cb.jpg',
#  'data/obj/004189a5e37ce5ec.jpg',
#  'data/obj/0041cc00de30cd96.jpg',
#  'data/obj/00439b1e36c54082.jpg',
#  'data/obj/0046c490ad699ce9.jpg',
#  'data/obj/0046e450842a601d.jpg',
#  'data/obj/00482b01579b3cc4.jpg',
#  'data/obj/004a0bae867ccc90.jpg',
#  'data/obj/004a67f661873881.jpg',
#  'data/obj/004c44f7d2bc28e7.jpg',
#  'data/obj/004c9e62d8e709be.jpg',
#  'data/obj/004cd0d7c7cca954.jpg',
#  'data/obj/004d6584538801e7.jpg',
#  'data/obj/004d73db0ae8e467.jpg',
#  'data/obj/004e831e8776c027.jpg',
#  'data/obj/004f1e43877d3820.jpg',
#  'data/obj/0050e8dc77246dff.jpg',
#  'data/obj/005184e7c592bcbb.jpg',
#  'data/obj/0051c398936d031e.jpg',
#  'data/obj/00529966a91519f8.jpg',
#  'data/obj/0052b4d0dda75747.jpg',
#  'data/obj/0053cc60862aecd8.jpg',
#  'data/obj/005497790b7b56f3.jpg',
#  'data/obj/00550fdf3e35a59b.jpg',
#  'data/obj/005527c8b705bb5d.jpg',
#  'data/obj/005553035e586a56.jpg',
#  'data/obj/005553933e7de4d4.jpg',
#  'data/obj/00560e800a9ec966.jpg',
#  'data/obj/00562ca23aa5b4b9.jpg',
#  'data/obj/00563f4c3933cc62.jpg',
#  'data/obj/0058b956bb1fd38d.jpg',
#  'data/obj/00591a9891b2e5fa.jpg',
#  'data/obj/00596251e5c6a80a.jpg',
#  'data/obj/0059a08cabca42a6.jpg',
#  'data/obj/0059d8c3c5c6569b.jpg',
#  'data/obj/005a025b07a24852.jpg',
#  'data/obj/005b380989c245bc.jpg',
#  'data/obj/005b708f05e4e9b9.jpg',
#  'data/obj/005b994faec6568a.jpg',
#  'data/obj/005cb2547672aace.jpg',
#  'data/obj/005dd740ace87a71.jpg',
#  'data/obj/0061aad2606d4eeb.jpg',
#  'data/obj/0061ef57274343be.jpg',
#  'data/obj/00622487a4998b43.jpg',
#  'data/obj/00639dc8bc77a5d9.jpg',
#  'data/obj/00647cbfb1f2e96b.jpg',
#  'data/obj/00655ec25dbafe58.jpg',
#  'data/obj/0066b9829275e289.jpg',
#  'data/obj/006a7af5bd1e57e8.jpg',
#  'data/obj/006e15b7e76cc22f.jpg',
#  'data/obj/006e8052b7a5f1e2.jpg',
#  'data/obj/006f4870f0a038de.jpg',
#  'data/obj/006fc1be2a6820d5.jpg',
#  'data/obj/006ff0fc7572a4e6.jpg',
#  'data/obj/00705b9a8bc244c8.jpg',
#  'data/obj/0070d231aa19f640.jpg',
#  'data/obj/0072ffbcd06d41c5.jpg',
#  'data/obj/007392f07b74adb6.jpg',
#  'data/obj/0074375a24243c9a.jpg',
#  'data/obj/0075f5e3cd0a0419.jpg',
#  'data/obj/00767741b82e7e22.jpg',
#  'data/obj/007685f57c564338.jpg',
#  'data/obj/007af8fe05e72480.jpg',
#  'data/obj/007b7da062b02c19.jpg',
#  'data/obj/007ba83606c7456b.jpg',
#  'data/obj/007bc5e7d1705191.jpg',
#  'data/obj/007bef94639c1b0c.jpg',
#  'data/obj/007c3d6093d0635b.jpg',
#  'data/obj/007ca4b87fd9e752.jpg',
#  'data/obj/007cd359c8e7d81c.jpg',
#  'data/obj/007ddc1bc04a5035.jpg',
#  'data/obj/0080db5bf6a6bc8d.jpg',
#  'data/obj/0081eba3f19526fa.jpg',
#  'data/obj/008214f5a1c33064.jpg',
#  'data/obj/00822b15f28129c5.jpg',
#  'data/obj/0082b080d73ad659.jpg',
#  'data/obj/008477316c5aabd9.jpg',
#  'data/obj/0084fe212a0eacc1.jpg',
#  'data/obj/008516cf94ef257b.jpg',
#  'data/obj/00880b686c65c82a.jpg',
#  'data/obj/00894c5181807806.jpg',
#  'data/obj/00897690334056dd.jpg',
#  'data/obj/0089b83773fe821a.jpg',
#  'data/obj/008a0c001ea6cd48.jpg',
#  'data/obj/008a96c1ffc85dff.jpg',
#  'data/obj/008ab3a0d729f6a6.jpg',
#  'data/obj/008af851d93e1205.jpg',
#  'data/obj/008b292096055fb6.jpg',
#  'data/obj/008b560be437b75d.jpg',
#  'data/obj/008bb4a176a4dfe8.jpg',
#  'data/obj/008cb05c28f67aeb.jpg',
#  'data/obj/008d346b1b7c75f8.jpg',
#  'data/obj/008ddae61fc1c661.jpg',
#  'data/obj/008de609f206d34e.jpg',
#  'data/obj/008fa17571511f5f.jpg',
#  'data/obj/008fb3ebd2da670f.jpg',
#  'data/obj/008fe0a507210a0b.jpg',
#  'data/obj/00936ecdeec72065.jpg',
#  'data/obj/0095d49d529409d1.jpg',
#  'data/obj/0097b6e8592ceeb5.jpg',
#  'data/obj/00980ca30c06bc4c.jpg',
#  'data/obj/0098cdb2e0236c93.jpg',
#  'data/obj/0099f0645486e21c.jpg',
#  'data/obj/009a0c84e1db235e.jpg',
#  'data/obj/009b7fd7b38316a4.jpg',
#  'data/obj/009bc1de7a055571.jpg',
#  'data/obj/009c3e4107fd2a2a.jpg',
#  'data/obj/009d7b2fb1c67a98.jpg',
#  'data/obj/009ddb55e0f91793.jpg',
#  'data/obj/009efd29da4201b4.jpg',
#  'data/obj/009fef508e31f282.jpg',
#  'data/obj/00a109d072e06c56.jpg',
#  'data/obj/00a15b092a907e62.jpg',
#  'data/obj/00a42071510621d3.jpg',
#  'data/obj/00a47216c9c9aa04.jpg',
#  'data/obj/00a4b9f1eea5d193.jpg',
#  'data/obj/00a5279c4c33ab1e.jpg',
#  'data/obj/00a561dd8cd4fa40.jpg',
#  'data/obj/00a564d6346afeab.jpg',
#  'data/obj/00a66ce1052f012b.jpg',
#  'data/obj/00a691fd53b899b4.jpg',
#  'data/obj/00a6e2422cc8d19b.jpg',
#  'data/obj/00a7eaca6543a35e.jpg',
#  'data/obj/00a87a76a03ab91c.jpg',
#  'data/obj/00ad7e386df8be46.jpg',
#  'data/obj/00ae2b97174ba23a.jpg',
#  'data/obj/00af217a66b8d5c0.jpg',
#  'data/obj/00b243164ff2398b.jpg',
#  'data/obj/00b7016c87625c64.jpg',
#  'data/obj/00b93cf08e49ad11.jpg',
#  'data/obj/00b95527ff06762f.jpg',
#  'data/obj/00ba3c9c8a062e4b.jpg',
#  'data/obj/00ba434123c44b19.jpg',
#  'data/obj/00bae41b6308c440.jpg',
#  'data/obj/00bb0c471b36fe5a.jpg',
#  'data/obj/00bc11981bc35c31.jpg',
#  'data/obj/00bd04e2898cf23c.jpg',
#  'data/obj/00bee6efb1dbcc71.jpg',
#  'data/obj/00bf2a483365f41d.jpg',
#  'data/obj/00bf64c01afbdc23.jpg',
#  'data/obj/00bfaa5b2b04d64e.jpg',
#  'data/obj/00c056284e104b4a.jpg',
#  'data/obj/00c1912fbb219332.jpg',
#  'data/obj/00c365cb6de858dc.jpg',
#  'data/obj/00c7702fe2b5cacc.jpg',
#  'data/obj/00ca0e6cb5458763.jpg',
#  'data/obj/00ccc65682887134.jpg',
#  'data/obj/00cd66ab36a4bd25.jpg',
#  'data/obj/00cd866870478844.jpg',
#  'data/obj/00ceec67a7ed3361.jpg',
#  'data/obj/00d12d1875ce40ef.jpg',
#  'data/obj/00d16a47d9701118.jpg',
#  'data/obj/00d3e3339e3410cd.jpg',
#  'data/obj/00d4dba736e34ec7.jpg',
#  'data/obj/00d5478aeed377bd.jpg',
#  'data/obj/00d5ddd0867382b6.jpg',
#  'data/obj/00d65f7aa9558f1e.jpg',
#  'data/obj/00dab69c13882252.jpg',
#  'data/obj/00dddbb0de019faf.jpg',
#  'data/obj/00deb9878c303411.jpg',
#  'data/obj/00dede04dadf2f36.jpg',
#  'data/obj/00df498bf80fc33e.jpg',
#  'data/obj/00dfce665f139242.jpg',
#  'data/obj/00dfe333d5a4b7c8.jpg',
#  'data/obj/00e093d6bf549702.jpg',
#  'data/obj/00e0b6bb1f6ed9c5.jpg',
#  'data/obj/00e23491475e19a4.jpg',
#  'data/obj/00e32abf6c3f5cae.jpg',
#  'data/obj/00e4678d94c8c83f.jpg',
#  'data/obj/00e4cdd4de23f392.jpg',
#  'data/obj/00e4de5392c887a1.jpg',
#  'data/obj/00e4e3250edc644a.jpg',
#  'data/obj/00e66d96f0d60f94.jpg',
#  'data/obj/00e7591c63cabc41.jpg',
#  'data/obj/00e78cf61e791c50.jpg',
#  'data/obj/00e8b2002432c190.jpg',
#  'data/obj/00e9fa5f3c172479.jpg',
#  'data/obj/00eb68c0124cb8ae.jpg',
#  'data/obj/00ebd54d740318fe.jpg',
#  'data/obj/00ecc6ef2d0704c9.jpg',
#  'data/obj/00eea68d629438c4.jpg',
#  'data/obj/00eeb3b9c2c9f9a5.jpg',
#  'data/obj/00f0c2555b31e87e.jpg',
#  'data/obj/00f0f12cd06bb7f1.jpg',
#  'data/obj/00f114eade2264f4.jpg',
#  'data/obj/00f34b41c940fba8.jpg',
#  'data/obj/00f3f50e0d56191a.jpg',
#  'data/obj/00f4de8a765ff5c9.jpg',
#  'data/obj/00f5c459cbc397df.jpg',
#  'data/obj/00f5ce4a2f13c622.jpg',
#  'data/obj/00f5fef95997e308.jpg',
#  'data/obj/00f60083487a996e.jpg',
#  'data/obj/00f6acbdf1c6821b.jpg',
#  'data/obj/00f8a13b3a732191.jpg',
#  'data/obj/00f8f1d389df976e.jpg',
#  'data/obj/00f944f3c7fc4f8f.jpg',
#  'data/obj/00f9c4a3ec516728.jpg',
#  'data/obj/00fc3a9b2c2bb410.jpg',
#  'data/obj/00fc540438b5dbc1.jpg',
#  'data/obj/00ff237d39c49022.jpg',
#  'data/obj/00ffeff035ef4672.jpg',
#  'data/obj/01000bae48b2887a.jpg',
#  'data/obj/010174b218e16fc8.jpg',
#  'data/obj/0102d63ab2539bcd.jpg',
#  'data/obj/01036f558eed822a.jpg',
#  'data/obj/0103801e1f1d43b6.jpg',
#  'data/obj/01048a393e78a080.jpg',
#  'data/obj/0104c70b45119535.jpg',
#  'data/obj/010530da675afa22.jpg',
#  'data/obj/0105df37cb415495.jpg',
#  'data/obj/01076695ee6fb364.jpg',
#  'data/obj/0107a0e53a0811eb.jpg',
#  'data/obj/0109a0e3e323ca06.jpg',
#  'data/obj/0109f7dc0168724c.jpg',
#  'data/obj/010ae41435c24ca2.jpg',
#  'data/obj/010cdca4a3893924.jpg',
#  'data/obj/010f52d8b88eca10.jpg',
#  'data/obj/010f66a24e9528ba.jpg',
#  'data/obj/010f95124ea0503f.jpg',
#  'data/obj/010fd5e6d6f9ae8f.jpg',
#  'data/obj/01124b8875752d31.jpg',
#  'data/obj/0112760b4f6d9a4a.jpg',
#  'data/obj/0114517ae790f0bd.jpg',
#  'data/obj/0114d9fb2d48f2e1.jpg',
#  'data/obj/01153e130541cb67.jpg',
#  'data/obj/011576be14fd1751.jpg',
#  'data/obj/0116428bd55fc6d2.jpg',
#  'data/obj/0117b9c1794a0acb.jpg',
#  'data/obj/011bc7a01c1d1581.jpg',
#  'data/obj/011ddddb7a59e003.jpg',
#  'data/obj/011f4046d8684418.jpg',
#  'data/obj/01205238220dfea2.jpg',
#  'data/obj/0121278058cbc221.jpg',
#  'data/obj/01216ff184cc3d41.jpg',
#  'data/obj/01219c8c09f90894.jpg',
#  'data/obj/012478889e7262e2.jpg',
#  'data/obj/012528a3e7837b57.jpg',
#  'data/obj/01255d64e416bb88.jpg',
#  'data/obj/01266d423626225e.jpg',
#  'data/obj/0129bb8d6c18ea01.jpg',
#  'data/obj/012bfbbf10a76807.jpg',
#  'data/obj/012c6f911bff6da0.jpg',
#  'data/obj/012e946d0be4b867.jpg',
#  'data/obj/012ea8d46d0b22ed.jpg',
#  'data/obj/012f94425ec84275.jpg',
#  'data/obj/0130a5b28b6a2e2d.jpg',
#  'data/obj/013702d6f9cce059.jpg',
#  'data/obj/013777c51de61c9f.jpg',
#  'data/obj/0138949683db0e54.jpg',
#  'data/obj/013903943cb6a6d9.jpg',
#  'data/obj/0139fbff117e23ca.jpg',
#  'data/obj/013b2858b5d84662.jpg',
#  'data/obj/013dbbc8737c642c.jpg',
#  'data/obj/013dd1e823c2c97a.jpg',
#  'data/obj/013e77a70355f66b.jpg',
#  'data/obj/0141168d94df7680.jpg',
#  'data/obj/014290fc68ef543a.jpg',
#  'data/obj/014323e95ec7c1ff.jpg',
#  'data/obj/014416747e92bf90.jpg',
#  'data/obj/0147fa477c075d90.jpg',
#  'data/obj/014a7f8aa65cdacc.jpg',
#  'data/obj/014aafb8e8aff4d7.jpg',
#  'data/obj/014b5857d4f99196.jpg',
#  'data/obj/014b66991e05e1d2.jpg',
#  'data/obj/014c03cfe8877d07.jpg',
#  'data/obj/014ed5861c4fb646.jpg',
#  'data/obj/014f58d101d1e7a9.jpg',
#  'data/obj/014f861a85298382.jpg',
#  'data/obj/0150930196450f5c.jpg',
#  'data/obj/01522a7d94cfb376.jpg',
#  'data/obj/015237fae1789950.jpg',
#  'data/obj/015287b2c76ad400.jpg',
#  'data/obj/0152e6a10d2a9aae.jpg',
#  'data/obj/0153e56d7824211d.jpg',
#  'data/obj/0155b72df50cd263.jpg',
#  'data/obj/015668b844332d3f.jpg',
#  'data/obj/0158022df25dc400.jpg',
#  'data/obj/015897da68815bac.jpg',
#  'data/obj/0159db8f35688fff.jpg',
#  'data/obj/015c2e9170199bfd.jpg',
#  'data/obj/015ca4e8dd3baf2d.jpg',
#  'data/obj/015e914dd254e26b.jpg',
#  'data/obj/015f4dcda9643329.jpg',
#  'data/obj/016083796331bd47.jpg',
#  'data/obj/0160e0b175401fa4.jpg',
#  'data/obj/016224b71dbc9c55.jpg',
#  'data/obj/01642c5cf8fab697.jpg',
#  'data/obj/0166d1b43ad81fd0.jpg',
#  'data/obj/01695c4f1dc8568e.jpg',
#  'data/obj/016989249c98dcab.jpg',
#  'data/obj/0169f45a0ec71c93.jpg',
#  'data/obj/016a0fd14ca4448e.jpg',
#  'data/obj/016a7ae288178c53.jpg',
#  'data/obj/016ad20ea887acda.jpg',
#  'data/obj/016b04f0d5aa9dfb.jpg',
#  'data/obj/016ce592cf20fee1.jpg',
#  'data/obj/016ee8e08f109e81.jpg',
#  'data/obj/016f4c9c74d69f34.jpg',
#  'data/obj/016f580f6deff203.jpg',
#  'data/obj/0174c84fefcf42b1.jpg',
#  'data/obj/0175d8fa3f1bb57f.jpg',
#  'data/obj/017901584dbd10e4.jpg',
#  'data/obj/017da1bdf12bf8f6.jpg',
#  'data/obj/017dad8df7434816.jpg',
#  'data/obj/017f805345e6ec80.jpg',
#  'data/obj/01814329a5cf02ea.jpg',
#  'data/obj/0182c1dff887679b.jpg',
#  'data/obj/01844bb119e15c0a.jpg',
#  'data/obj/0185beba79fda029.jpg',
#  'data/obj/018757575efe57b3.jpg',
#  'data/obj/018d1e0ddc80e4a6.jpg',
#  'data/obj/018dea1fc40a7910.jpg',
#  'data/obj/018eb6c94fe5964e.jpg',
#  'data/obj/018fbec11085bc5e.jpg',
#  'data/obj/0190f75c0d0fc20d.jpg',
#  'data/obj/019147627ec100f7.jpg',
#  'data/obj/01923ff895722c33.jpg',
#  'data/obj/01928e0006f68d34.jpg',
#  'data/obj/0192dd16b3c12eda.jpg',
#  'data/obj/0193062513467f09.jpg',
#  'data/obj/019354126d193940.jpg',
#  'data/obj/019549b3a50bed53.jpg',
#  'data/obj/019583750946f76d.jpg',
#  'data/obj/01959015cebc27b8.jpg',
#  'data/obj/0195b26740897b9a.jpg',
#  'data/obj/0196ce1e3ea9c7db.jpg',
#  'data/obj/01979b0d9bba1f20.jpg',
#  'data/obj/0197b5048a0c0b2c.jpg',
#  'data/obj/019a5c7c4d1a5066.jpg',
#  'data/obj/019a786662cc690c.jpg',
#  'data/obj/019fd6797b2663fc.jpg',
#  'data/obj/01a0b68f6a769f98.jpg',
#  'data/obj/01a2115a58b2dbbb.jpg',
#  'data/obj/01a28da813824f21.jpg',
#  'data/obj/01a37befc59983e4.jpg',
#  'data/obj/01a3e1205d6ba145.jpg',
#  'data/obj/01a4d4a9ca88792f.jpg',
#  'data/obj/01a5ef73f29d3d7d.jpg',
#  'data/obj/01a608e444e62d07.jpg',
#  'data/obj/01a67e23a4e63bcd.jpg',
#  'data/obj/01a85e7d6bead1dc.jpg',
#  'data/obj/01aa3d21b1069a24.jpg',
#  'data/obj/01aa928500d7da59.jpg',
#  'data/obj/01ab2ac6e9ffdfa6.jpg',
#  'data/obj/01acbef71b164e71.jpg',
#  'data/obj/01ae3b71fa767fb6.jpg',
#  'data/obj/01aeec8d05bb1edf.jpg',
#  'data/obj/01af206ab6e5ea50.jpg',
#  'data/obj/01afa9c73f5f63af.jpg',
#  'data/obj/01b3ac9888ab86f4.jpg',
#  'data/obj/01b3bd02c18a0a18.jpg',
#  'data/obj/01b7ec9318949710.jpg',
#  'data/obj/01bce298f57113a8.jpg',
#  'data/obj/01bd3c8da9a41a0e.jpg',
#  'data/obj/01bee40c186707cf.jpg',
#  'data/obj/01c038cb769f8c3b.jpg',
#  'data/obj/01c156e443dca228.jpg',
#  'data/obj/01c1bf9bccd6b72e.jpg',
#  'data/obj/01c5c5f37c9e3c42.jpg',
#  'data/obj/01c5fc1b56dace92.jpg',
#  'data/obj/01cc6700eba1ed0c.jpg',
#  'data/obj/01cd01e2ae7d711b.jpg',
#  'data/obj/01cd6bb4620fdb2e.jpg',
#  'data/obj/01d28ce30ce1d1d9.jpg',
#  'data/obj/01d372697a4fcccd.jpg',
#  'data/obj/01d46638484e5be6.jpg',
#  'data/obj/01d5514fa23ca826.jpg',
#  'data/obj/01d601bbd986dc00.jpg',
#  'data/obj/01d6d4bf10d04ef1.jpg',
#  'data/obj/01db7cecd1ae56ba.jpg',
#  'data/obj/01dce908cfce7cb8.jpg',
#  'data/obj/01dd6c025c5a2696.jpg',
#  'data/obj/01e00b6292202ddd.jpg',
#  'data/obj/01e06c8c3f9e45ab.jpg',
#  'data/obj/01e0efbebd32b28b.jpg',
#  'data/obj/01e7cb871f08cad8.jpg',
#  'data/obj/01ea25d63fa4e9a2.jpg',
#  'data/obj/01ef84b276eb9374.jpg',
#  'data/obj/01ef8ceed648c5c0.jpg',
#  'data/obj/01f05b161bfca06c.jpg',
#  'data/obj/01f1fd110788ba35.jpg',
#  'data/obj/01f2d386135051e1.jpg',
#  'data/obj/01f34e9aaddf853f.jpg',
#  'data/obj/01f3af3b52359dce.jpg',
#  'data/obj/01f45d9e0f218c7c.jpg',
#  'data/obj/01f4feb5d923c766.jpg',
#  'data/obj/01f50c12a6bdf183.jpg',
#  'data/obj/01f6de3cada9ed50.jpg',
#  'data/obj/01f7b50c985db47b.jpg',
#  'data/obj/01f8fac72a33ade7.jpg',
#  'data/obj/01f941894550eafb.jpg',
#  'data/obj/01f948d66fa6e639.jpg',
#  'data/obj/01fc8d4b51eb974c.jpg',
#  'data/obj/01fcc8469cc48d41.jpg',
#  'data/obj/01fccb7719d188b7.jpg',
#  'data/obj/01fe66599a1c105f.jpg',
#  'data/obj/01ff97c991eacf03.jpg',
#  'data/obj/01ffe5a57ccff9c6.jpg',
#  'data/obj/020210f318670e65.jpg',
#  'data/obj/020253a430a408b3.jpg',
#  'data/obj/0207dc06fbfbe3f8.jpg',
#  'data/obj/0208bc6ff8213d68.jpg',
#  'data/obj/02093f5963e1c446.jpg',
#  'data/obj/020ac58deedbf707.jpg',
#  'data/obj/020c154e941a7cbb.jpg',
#  'data/obj/020c6682584da59d.jpg',
#  'data/obj/020e69654f6100c2.jpg',
#  'data/obj/02109515686fd1d6.jpg',
#  'data/obj/0210d7be91ad7b4a.jpg',
#  'data/obj/0211cbabe2971c34.jpg',
#  'data/obj/02127dc44c18b70c.jpg',
#  'data/obj/021300f3cb36e682.jpg',
#  'data/obj/021525376d76b955.jpg',
#  'data/obj/0216708ade9495b3.jpg',
#  'data/obj/021751c5da0137bb.jpg',
#  'data/obj/0217c2cb8498f8b5.jpg',
#  'data/obj/021a190dcda6c4e7.jpg',
#  'data/obj/021bbe81bafdaaed.jpg',
#  'data/obj/021c8c191f0bb20f.jpg',
#  'data/obj/021ea6e5c812aa9b.jpg',
#  'data/obj/021f0ca2921c0b08.jpg',
#  'data/obj/021f288da777707f.jpg',
#  'data/obj/021fbd253584f637.jpg',
#  'data/obj/021fd907fa3996ec.jpg',
#  'data/obj/022674b2f72c4410.jpg',
#  'data/obj/0226c58a0ebb5a44.jpg',
#  'data/obj/02280fb220fc2354.jpg',
#  'data/obj/02281fd57a46231f.jpg',
#  'data/obj/0228e1c64e7416b9.jpg',
#  'data/obj/022a19fe02ba8030.jpg',
#  'data/obj/022aa2e170a8011c.jpg',
#  'data/obj/022b01b33dccc463.jpg',
#  'data/obj/022b47f1dcf5e4c0.jpg',
#  'data/obj/022bec0f5eb2c855.jpg',
#  'data/obj/022ca3f59e32234a.jpg',
#  'data/obj/022dd2a52674fe23.jpg',
#  'data/obj/022e6a00b3d54a94.jpg',
#  'data/obj/0234cad70c042436.jpg',
#  'data/obj/023857447deb265d.jpg',
#  'data/obj/0239191431863f64.jpg',
#  'data/obj/0239b65009ba5ab7.jpg',
#  'data/obj/023a0359cf617068.jpg',
#  'data/obj/023b9cc6371553e1.jpg',
#  'data/obj/023c1c117ac60ff0.jpg',
#  'data/obj/023c427f9eda947f.jpg',
#  'data/obj/023dcff8a539598a.jpg',
#  'data/obj/02402946e8206fcc.jpg',
#  'data/obj/0243adc3be990a12.jpg',
#  'data/obj/02496f861830466e.jpg',
#  'data/obj/0249e770301fd69b.jpg',
#  'data/obj/024ab92488978aaf.jpg',
#  'data/obj/024b1ed5774c1045.jpg',
#  'data/obj/024ba04fcbb10b26.jpg',
#  'data/obj/024c87cd19198fce.jpg',
#  'data/obj/0250c76141d86ad5.jpg',
#  'data/obj/0252f2792994457a.jpg',
#  'data/obj/02535f11fe866e85.jpg',
#  'data/obj/02545e08a33e732b.jpg',
#  'data/obj/0255360c4cc88eb9.jpg',
#  'data/obj/025654da39dd8ce4.jpg',
#  'data/obj/025add2ead11e903.jpg',
#  'data/obj/025c22a977b12e47.jpg',
#  'data/obj/02604bb96a5af36d.jpg',
#  'data/obj/02619c2146c157e2.jpg',
#  'data/obj/0262e49db658fc7c.jpg',
#  'data/obj/0265a0cbc07582d1.jpg',
#  'data/obj/026c67083ca5ca40.jpg',
#  'data/obj/026ce9ba7ba94867.jpg',
#  'data/obj/026dad5a7df26282.jpg',
#  'data/obj/02724a76b0b92e14.jpg',
#  'data/obj/0272bc1d146faea0.jpg',
#  'data/obj/0275da1d6578bbd5.jpg',
#  'data/obj/0277fd03aa57f423.jpg',
#  'data/obj/027807cd4b583436.jpg',
#  'data/obj/027c248bc41110ef.jpg',
#  'data/obj/027c5adfe6c0d84b.jpg',
#  'data/obj/027f1c5f4cd3ebe9.jpg',
#  'data/obj/028058d7d267e18a.jpg',
#  'data/obj/02818b2aa5b806be.jpg',
#  'data/obj/0281b56383336aea.jpg',
#  'data/obj/02845b4ca1ae01c1.jpg',
#  'data/obj/02857f54627efc1b.jpg',
#  'data/obj/0287821fd31daf90.jpg',
#  'data/obj/0289233f3f1544f7.jpg',
#  'data/obj/028b0880e9513536.jpg',
#  'data/obj/028b8dea7a3243e5.jpg',
#  'data/obj/028cea472af18db7.jpg',
#  'data/obj/028ef5914ce9c09e.jpg',
#  'data/obj/0290b21ac97fe106.jpg',
#  'data/obj/0290e8342b26ea8d.jpg',
#  'data/obj/0291019bd62da03f.jpg',
#  'data/obj/02914a79b9d74a6e.jpg',
#  'data/obj/0292f183034d3e03.jpg',
#  'data/obj/0293475f300e34ba.jpg',
#  'data/obj/02934eb1cf9ceab3.jpg',
#  'data/obj/0293ae9a3492a031.jpg',
#  'data/obj/0293cdee1b4b4b2b.jpg',
#  'data/obj/02953879198d33e8.jpg',
#  'data/obj/02976e4bf78e6693.jpg',
#  'data/obj/0297f4c0171b5ad1.jpg',
#  'data/obj/029cb57bb94d4f18.jpg',
#  'data/obj/029d4c8f2f2b36f8.jpg',
#  'data/obj/02a01b669049ee2e.jpg',
#  'data/obj/02a0c5b13e17341e.jpg',
#  'data/obj/02a884e9c5149358.jpg',
#  'data/obj/02a9da3d3a9cd823.jpg',
#  'data/obj/02aa858a509d63f7.jpg',
#  'data/obj/02abdfdfc3abc318.jpg',
#  'data/obj/02abf240ba7952fd.jpg',
#  'data/obj/02acaaa905c2ef9c.jpg',
#  'data/obj/02dc1de441b917a5.jpg',
#  'data/obj/02dcd7cf2d5deeca.jpg',
#  'data/obj/02dcf39801858a76.jpg',
#  'data/obj/02e06a62ac2b0610.jpg',
#  'data/obj/02e1e5ed7e676469.jpg',
#  'data/obj/02e2b829deb2b793.jpg',
#  'data/obj/02e2bd68d15fcf26.jpg',
#  'data/obj/02e44f250202a55d.jpg',
#  'data/obj/02e4d3153679142d.jpg',
#  'data/obj/02e661b2e022ee05.jpg',
#  'data/obj/02e8af456baf1c78.jpg',
#  'data/obj/02e9d4897c92545e.jpg',
#  'data/obj/02eb8f5ddde47d94.jpg',
#  'data/obj/02ed65aa0cec6832.jpg',
#  'data/obj/02f1126d808e7a75.jpg',
#  'data/obj/02f33b961bc12cde.jpg',
#  'data/obj/02f79bd5d1e116c2.jpg',
#  'data/obj/02f8ba65cf8e52fc.jpg',
#  'data/obj/02f8f6df556dcc82.jpg',
#  'data/obj/02fa2c8b9ded2c45.jpg',
#  'data/obj/02fb0eb378f1276e.jpg',
#  'data/obj/02fcdf16070e6089.jpg',
#  'data/obj/02fe644f422888e7.jpg',
#  'data/obj/02fec799175aa747.jpg',
#  'data/obj/03002b55a7d24b3f.jpg',
#  'data/obj/03024f5fb0c28db4.jpg',
#  'data/obj/0302946c1f90b566.jpg',
#  'data/obj/0304cf1f3da77c8b.jpg',
#  'data/obj/03052c989a8ab394.jpg',
#  'data/obj/03062be59f894264.jpg',
#  'data/obj/0308d2493291700b.jpg',
#  'data/obj/030988ee4ccd2750.jpg',
#  'data/obj/030e80cc5dc7e2c2.jpg',
#  'data/obj/030f48f80fc1d61a.jpg',
#  'data/obj/0312f7baac313682.jpg',
#  'data/obj/0313937cba5703dd.jpg',
#  'data/obj/0315c3b4099bbc8c.jpg',
#  'data/obj/03163e6cc8ea7667.jpg',
#  'data/obj/03174ad7b5cf4a3b.jpg',
#  'data/obj/0317be2f1f30f938.jpg',
#  'data/obj/0318401b970faec5.jpg',
#  'data/obj/03198d00d17c9182.jpg',
#  'data/obj/031dd48c9606a5e5.jpg',
#  'data/obj/03251ad15b651704.jpg',
#  'data/obj/0325475fc6e22113.jpg',
#  'data/obj/0325bdf031e4fc68.jpg',
#  'data/obj/03274ad6d556a104.jpg',
#  'data/obj/032757102dedc2a3.jpg',
#  'data/obj/0328f8a45cb9f5d3.jpg',
#  'data/obj/032d4caead7d4a33.jpg',
#  'data/obj/032d8ad6facf750b.jpg',
#  'data/obj/032dbe6880c52047.jpg',
#  'data/obj/032e1bada7a4eade.jpg',
#  'data/obj/0331210f71b94cc9.jpg',
#  'data/obj/0336a29813c1bbf7.jpg',
#  'data/obj/033727c1c55fb41a.jpg',
#  'data/obj/033bc9d560f537c3.jpg',
#  'data/obj/033d5de990dd861c.jpg',
#  'data/obj/0340f3dc36a633eb.jpg',
#  'data/obj/03425a5db8db629b.jpg',
#  'data/obj/03448fe1734a76c7.jpg',
#  'data/obj/0344fdb4f327f726.jpg',
#  'data/obj/0345d05f1205536b.jpg',
#  'data/obj/03463c2bb329631c.jpg',
#  'data/obj/034643b6fb1eb126.jpg',
#  'data/obj/03466b6e5d7ba913.jpg',
#  'data/obj/03472b4ee462c1f5.jpg',
#  'data/obj/034833f9c2bfdc5b.jpg',
#  'data/obj/034ee3cc5ff5eaaf.jpg',
#  'data/obj/0355a10c9f8cd6d1.jpg',
#  'data/obj/035774a2068abcf6.jpg',
#  'data/obj/0357d01b50e65d0d.jpg',
#  'data/obj/035923a4615addd1.jpg',
#  'data/obj/03598394010d8431.jpg',
#  'data/obj/035a5e14f05bd2ac.jpg',
#  'data/obj/035ace359100b51f.jpg',
#  'data/obj/035c73c6173038ab.jpg',
#  'data/obj/035c7b162eb36689.jpg',
#  'data/obj/035ca93ba11c41fe.jpg',
#  'data/obj/035e660c1e16431d.jpg',
#  'data/obj/035e78993f8fced8.jpg',
#  'data/obj/0361a73b58fe9c12.jpg',
#  'data/obj/0365956f4b361cb4.jpg',
#  'data/obj/0366906421192ca6.jpg',
#  'data/obj/0366c05a98cd6efc.jpg',
#  'data/obj/0369a628179ddc59.jpg',
#  'data/obj/036c127c9a8f7ab5.jpg',
#  'data/obj/0370a748cbb407af.jpg',
#  'data/obj/03712026fb36d705.jpg',
#  'data/obj/0371487a14930318.jpg',
#  'data/obj/03784e2bf7501ddd.jpg',
#  'data/obj/037851a3b5c61e8f.jpg',
#  'data/obj/037e35120276467b.jpg',
#  'data/obj/0380751138bb5db0.jpg',
#  'data/obj/03813d98fe561cc6.jpg',
#  'data/obj/0382c06b66bbb9f7.jpg',
#  'data/obj/03867639f6c20500.jpg',
#  'data/obj/0389ec6515b6161b.jpg',
#  'data/obj/038efe1dea5dacca.jpg',
#  'data/obj/038f3884377721e2.jpg',
#  'data/obj/038f550a2cb91ae1.jpg',
#  'data/obj/039091aae5af433a.jpg',
#  'data/obj/039133919a05dfb4.jpg',
#  'data/obj/0392eb372ff6ddcf.jpg',
#  'data/obj/03946fc767adb9ba.jpg',
#  'data/obj/0394c015862689bb.jpg',
#  'data/obj/03954e15213c5180.jpg',
#  'data/obj/039673d730c46204.jpg',
#  'data/obj/039720b2d24502f4.jpg',
#  'data/obj/0397890d1126121b.jpg',
#  'data/obj/0399e05ceb8bea0b.jpg',
#  'data/obj/039b768fed83e650.jpg',
#  'data/obj/039ba3324a65eec6.jpg',
#  'data/obj/039c044600d132f2.jpg',
#  'data/obj/039c66bdef662de4.jpg',
#  'data/obj/039ded15cf3d482e.jpg',
#  'data/obj/039ea386c9b42aaa.jpg',
#  'data/obj/03a22bb8a1fd1d5e.jpg',
#  'data/obj/03a2a514a2e79614.jpg',
#  'data/obj/03a6060d1cf1fec5.jpg',
#  'data/obj/03a614c12b898326.jpg',
#  'data/obj/03a6bdc9b90e9280.jpg',
#  'data/obj/03a77b4c5165f72d.jpg',
#  'data/obj/03a7aeaa047c60dc.jpg',
#  'data/obj/03a7d220a4125f2a.jpg',
#  'data/obj/03a7d44987d79c69.jpg',
#  'data/obj/03aa5513059820b8.jpg',
#  'data/obj/03aaf7be8e3ae608.jpg',
#  'data/obj/03b008c357d82de0.jpg',
#  'data/obj/03b236de57d205e0.jpg',
#  'data/obj/03b35c50b7f00bea.jpg',
#  'data/obj/03b456ec029451fb.jpg',
#  'data/obj/03b57dcddafc43b0.jpg',
#  'data/obj/03b60874ea0169ac.jpg',
#  'data/obj/03b78348610d1275.jpg',
#  'data/obj/03b89b3d7020e375.jpg',
#  'data/obj/03bb529be8a1e8df.jpg',
#  'data/obj/03bbd35890aea2a0.jpg',
#  'data/obj/03bc3712310ccc23.jpg',
#  'data/obj/03be90089c05d501.jpg',
#  'data/obj/03c3427e607e7800.jpg',
#  'data/obj/03c385b417d90ad5.jpg',
#  'data/obj/03c79131c1f66459.jpg',
#  'data/obj/03caaa746aa54902.jpg',
#  'data/obj/03cc0326508e8832.jpg',
#  'data/obj/03cd05a6e9f8f987.jpg',
#  'data/obj/03cd2407446fce20.jpg',
#  'data/obj/03ce893fcf7e5955.jpg',
#  'data/obj/03cfabed9af491ba.jpg',
#  'data/obj/03d25aaedc74a36e.jpg',
#  'data/obj/03d491a8dd79c3c6.jpg',
#  'data/obj/03d5bbd1c5d460e6.jpg',
#  'data/obj/03d6072124b02153.jpg',
#  'data/obj/03d8759fe8c28d61.jpg',
#  'data/obj/03db95a08ab8cbc9.jpg',
#  'data/obj/03de623f323edfc9.jpg',
#  'data/obj/03deb3345c22a2a1.jpg',
#  'data/obj/03e466a023999d0e.jpg',
#  'data/obj/03ea863e9cb5be16.jpg',
#  'data/obj/03eb546463a81634.jpg',
#  'data/obj/03ebbc7b94ecf803.jpg',
#  'data/obj/03f1c97e61e38358.jpg',
#  'data/obj/03f52c3dbdeb69f8.jpg',
#  'data/obj/03f7cf21133dfddb.jpg',
#  'data/obj/03fae40dd22fce98.jpg',
#  'data/obj/03fe1cda88f76e1b.jpg',
#  'data/obj/03febfab936a8021.jpg',
#  'data/obj/040050e87f2394f8.jpg',
#  'data/obj/0400ae2752fd04d3.jpg',
#  'data/obj/040121bf59bd4a3f.jpg',
#  'data/obj/040209b5f7ca508f.jpg',
#  'data/obj/0404bcb39ac980d6.jpg',
#  'data/obj/04075ea4a8c13c68.jpg',
#  'data/obj/04097d86bfab2000.jpg',
#  'data/obj/0409bc6208ce0d2f.jpg',
#  'data/obj/040a4c3f7e5c2a2e.jpg',
#  'data/obj/040b04e4515b61ab.jpg',
#  'data/obj/040b3c93a939cfac.jpg',
#  'data/obj/040b7e5271cddf55.jpg',
#  'data/obj/040b8de895a4e4ba.jpg',
#  'data/obj/040c0777eb33f432.jpg',
#  'data/obj/040ce3a19e6c0880.jpg',
#  'data/obj/040d952bcc7552f3.jpg',
#  'data/obj/040e3b004cfa82c2.jpg',
#  'data/obj/040f7a895e9986c8.jpg',
#  'data/obj/04113d3ea6aff2f4.jpg',
#  'data/obj/0411bab5f9022a43.jpg',
#  'data/obj/0412da46f55b1d67.jpg',
#  'data/obj/0412e4bf87141a66.jpg',
#  'data/obj/0412ea7c1b15e23f.jpg',
#  'data/obj/0413287c26572e5f.jpg',
#  'data/obj/0413a0aeedab5b3c.jpg',
#  'data/obj/0415bfcb07b1b92d.jpg',
#  'data/obj/041726e9d2050c1d.jpg',
#  'data/obj/0417a19c7fc9d8fa.jpg',
#  'data/obj/0418c2035f9a0798.jpg',
#  'data/obj/041903c927f63507.jpg',
#  'data/obj/041926a4858c0a9a.jpg',
#  'data/obj/041c09d129dbaf18.jpg',
#  'data/obj/041ff2d23c369b27.jpg',
#  'data/obj/04215cd1664e6c95.jpg',
#  'data/obj/04225c54a62d8edc.jpg',
#  'data/obj/042538a6cf554625.jpg']
