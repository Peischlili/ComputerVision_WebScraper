# %% [markdown]
# <h1>Image pre-processing for object-detection model</h1>
# <p style="color:blue;font-size:18px;">Step 1: Read imges</p>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import random

# %%
# Defining global variable path that contains train / train_resized folders
image_folder = "/Users/peisch/code/WebScraper/Images"

# Function to load folder into arrays and then it returns that same array
def loadImages(path):
    image_files = sorted([os.path.join(path, 'train', file)
         for file in os.listdir(path + "/train") if file.endswith('.jpg')])
    return image_files

# %%
# Check number of images in training set
len(loadImages(image_folder))
# Out:
# 946

# %% [markdown]
# <p style="color:blue;font-size:18px;">Step 2: Resize images</p>

# %%
# Display one image
def display_one(a, title1 = "Original"):
    plt.imshow(a), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.show()

# Display two images
def display(a, b, title1 = "Original", title2 = "Edited"):
    plt.subplot(121), plt.imshow(a), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(122), plt.imshow(b), plt.title(title2)
    plt.xticks([]), plt.yticks([])
    plt.show()

# %%
# Resize images into dimension determined and save resized images in new folder
# Generate a csv file including image information ie. origin weight/height, new width/height
# BE CAREFUL: we use "image_folder" global variable defined at the beginnning of the notebook

def resizing(data):
    
    # in the path given, create a folder for upcoming resized images if not existing
    os.chdir(image_folder)
    try:
        os.makedirs('train_resized')
        print("Resizing processing ... ")
    except FileExistsError:
        print("Directory 'train_resized' already exists. Resizing processing ... ")
        
    # Loop: for each image in the folder, store the 1/image, 2/origin size, 3/filename as imageId
    
    # create a dataframe to store information with determined typing for each column
    dtypes = np.dtype([
          ('imageId', str),
          ('origin_width', int),
          ('origin_height', int),
          ('new_width', int),
          ('new_height', int),
          ])
    empty_data = np.empty(0, dtype=dtypes)
    df = pd.DataFrame(empty_data)
    img_list = []
    
    # set working directory (folder) to store processed images
    working_dir = image_folder + "/train_resized/"
    os.chdir(working_dir)
        
    # setting dimemsion of the resized image and update count for processed images
    # be careful: for YoloV3 Darknet, image dimension has to be multiplication of 32 !!!
    count:int = 0
    height:int = 256
    width:int = 256
    dim = (width, height) # dimension is a tuple
    res_img = []
    
    # for each absolute path in the list 'data':
    # 1/read image; 2/get its origin image and imageID; 3/update image list;
    # 4/store info in dataframe; 5/store resized image in created "train_resized" folder
    
    for imgStr in data:
        img = [cv2.imread(imgStr, cv2.IMREAD_UNCHANGED)]
        origin_size = img[0].shape # shape of each image is a tuple of (height, weight, channel)
        origin_width = origin_size[1]
        origin_height = origin_size[0]
        imageId = imgStr.rstrip('.jpg').replace(f"{image_folder}/train/", "")
        img_list[len(img_list):] = [imageId] # equiv to "append" to a list
        
        # store info as a new row in the dataframe created above
        col_names = ['imageId', 'origin_width', 'origin_height', 'new_width', 'new_height']
        new_row = pd.DataFrame([[str(imageId), origin_width, origin_height, width, height]], columns = col_names)
        df = df.append(new_row)
        
        # resize image and store as .jpg in created folder
        res = cv2.resize(img[0], dim, interpolation=cv2.INTER_LINEAR)
        res_img.append(res)
        count = count + 1
        filename:str = imageId + ".jpg"
        cv2.imwrite(filename, res)
    
    # Checking the size after processing
    print(f"Resized image dimension : {res_img[-1].shape}. Example as follows:")
    
    # Visualizing one of the images in the array
    example_image = res_img[-1]
    display_one(example_image)
    
    # Delete duplicates of the df
    # Save dataframe into a CSV file (write or override .csv file)
    df = df.drop_duplicates()
    df.to_csv('imageTable.csv', index = False)
            
    print(f"Resizing finished. \n [ {count} ] image(s) resized and saved in directory: {working_dir} ")  
    return img_list

# %% [markdown]
# <p style="color:blue;font-size:18px;">Step 3: Recalculate image annotations</p>

# %%
def get_label(images):
    # set working dir to the resized folder 
    working_dir = image_folder + '/train_resized'
    os.chdir(working_dir)
    # load csv file containing image information
    df_img = pd.read_csv('imageTable.csv')
    df_img = df_img.set_index('imageId')
    
    dtypes = np.dtype([
          ('class', str),
          ('origin_xmin', int),
          ('origin_ymin', int),
          ('origin_xmax', int),
          ('origin_ymax', int),
          ('imageId', str)
          ])
    #empty_data = np.empty(0, dtype=dtypes)
    #df = pd.DataFrame(empty_data)
    
    image_buffer:str = ""
    
    for img in images:
        os.chdir(image_folder + '/train/Label')
        image_buffer = img
        filename = img + '.txt'
        # open origin .txt file and get information 
        try: 
            f = open(filename,"r")
            content = f.read()   
            # parse content and store in info list
            annotations = content.lstrip().rstrip().split('\n')
            annot_str:str = ""

            # each_annot is a string with shape: 'Dress', '483.84', '228.734651', '691.2', '683.0'
            for each_annot in annotations:
                # load info about the origin image stored in csv file
                line = df_img.loc[img]
                o_w = line['origin_width']
                o_h = line['origin_height']
                n_w = line['new_width']
                n_h = line['new_height']
                each_annot = each_annot.replace(",\n", ", ")
                # replace "Dress" by its class number (zero)
                each_annot = each_annot.replace("Dress", "0")
                # now access to information contained by dress and redo the annotation for Yolo3 model
                # annotation for Yolo3: x(centre), y(center), width, height (with all in range [0, 1])
                dress:list = each_annot.split(" ") #list
                xmin = dress[1]
                ymin = dress[2]
                xmax = dress[3]
                ymax = dress[4]
                x = (float(xmin) + float(xmax))/2/o_w
                y = (float(ymin) + float(ymax))/2/o_h
                box_w = (float(xmax)-float(xmin))/o_w
                box_h = (float(ymax)-float(ymin))/o_h
                # the string has the right form for yolo annotation
                each_box:str = f"0 {x} {y} {box_w} {box_h}"
                annot_str:str = each_box + "\n" + annot_str
            annot_str = annot_str.rstrip()
            f.close
        
        
            # create a folder to store .txt files named 'new_labels'
            os.chdir(image_folder)
            try: os.mkdir('train_resized') 
            except: FileExistsError
            os.chdir(image_folder + '/train_resized')    
            new_file = open(filename,"w")
            n = new_file.write(annot_str)
            new_file.close()
            
        except: FileNotFoundError
        
    print(f"New annotation .txt files had been saved in directory: {image_folder}/train_resized ")

# %% [markdown]
# <p style="color:blue;font-size:18px;">Step 4: Create train and test path files</p>

# %%
# this function is to produce train.txt and test.txt files used in Yolo3 training
def create_txt_file(img_list):
    # full path list
    store_list = []
    for i in range(len(img_list)): 
        img_path = f"data/obj/{img_list[i]}.jpg"
        store_list.append(img_path)
    
    # randomise train set and test set
    img_nb = len(store_list)
    # parameter of the dataset separation ratio
    train_r = 0.8
    test_r = 0.2
    train_nb = round(img_nb * train_r)
    test_nb = img_nb - train_nb
    
    train_index = random.sample(range(img_nb), k = train_nb)
    # train path list
    train_list = []
    for i in train_index : 
        path = store_list[i]
        train_list.append(path)
    # test path list
    test_list = list(set(store_list) - set(train_list))
    print(f"Set separation done. Train set size: {len(train_list)}. Test set size: {len(test_list)}.")
    
    # save those lists into .txt files
    # create a folder to store .txt files named 'train_test_file'
    os.chdir(image_folder)
    try: os.mkdir('train_test_path') 
    except: FileExistsError
    os.chdir(image_folder + '/train_test_path')
    
    # create and save train.txt
    train_str = '\n'.join(train_list)
    file1 = open("train.txt", "w")
    n = file1.write(train_str)
    file1.close()
    print(f"train.txt file had been saved in directory: {image_folder}/train_test_path")
    
     # create and save test.txt
    test_str = '\n'.join(test_list)
    file2 = open("test.txt", "w")
    n = file2.write(test_str)
    file2.close()
    print(f"test.txt file had been saved in directory: {image_folder}/train_test_path")
    
    return store_list

# %% [markdown]
# <p style="color:blue;font-size:18px;">Execute sequential functions</p>

# %%
# Load data with given image folder path
dataset = loadImages(image_folder)

# Call the resizing function over data and save imageTable.csv
images = resizing(dataset)

# Process all label .txt files and save new .txt files in new_labels folder
get_label(images)

# Create path file for Yolo3 training
create_txt_file(images)
# Out:
# Resizing processing ...
# Resized image dimension : (256, 256, 3). Example as follows:
# Resizing finished.
#  [ 946 ] image(s) resized and saved in directory: /Users/peisch/code/WebScraper/Images/train_resized/
# New annotation .txt files had been saved in directory: /Users/peisch/code/WebScraper/Images/train_resized
# Set separation done. Train set size: 757. Test set size: 189.
# train.txt file had been saved in directory: /Users/peisch/code/WebScraper/Images/train_test_path
# test.txt file had been saved in directory: /Users/peisch/code/WebScraper/Images/train_test_path
# ['data/obj/f85d775bf8d009fb.jpg',
#  'data/obj/f8629a58309eca82.jpg',
#  'data/obj/f869a6faf8b5a398.jpg',
#  'data/obj/f86b8d394511c28c.jpg',
#  'data/obj/f86ca1c35c776de7.jpg',
#  'data/obj/f86dbe57fb091db2.jpg',
#  'data/obj/f86e0319580fb878.jpg',
#  'data/obj/f871f218460cee06.jpg',
#  'data/obj/f872248b30a5fbcc.jpg',
#  'data/obj/f875455acc583e75.jpg',
#  'data/obj/f8759970439f4873.jpg',
#  'data/obj/f87d342824999b45.jpg',
#  'data/obj/f87e80f18f3980a4.jpg',
#  'data/obj/f87e9a009da1c7ed.jpg',
#  'data/obj/f87eaadc2b09c709.jpg',
#  'data/obj/f87ee0120f900425.jpg',
#  'data/obj/f87f13c1954bfb8a.jpg',
#  'data/obj/f8849fb57ee90835.jpg',
#  'data/obj/f8851323a845d66a.jpg',
#  'data/obj/f88688816e5a6c1c.jpg',
#  'data/obj/f88a626ea7b1986f.jpg',
#  'data/obj/f88a793e81750ac4.jpg',
#  'data/obj/f88d372ddadc066c.jpg',
#  'data/obj/f890bf7a70ade1cc.jpg',
#  'data/obj/f891659b6a7b7e3b.jpg',
#  'data/obj/f8926fa09aa40992.jpg',
#  'data/obj/f892b1f9be7ee323.jpg',
#  'data/obj/f894789b20dcb560.jpg',
#  'data/obj/f8973f2f918b9eb8.jpg',
#  'data/obj/f8974c706e3f2e06.jpg',
#  'data/obj/f898874ca20231aa.jpg',
#  'data/obj/f8992b5ee9b4c7b7.jpg',
#  'data/obj/f89afd71e0b270e3.jpg',
#  'data/obj/f89c0f2706e42119.jpg',
#  'data/obj/f8a156836aac4dd0.jpg',
#  'data/obj/f8a46cb2bf1090a6.jpg',
#  'data/obj/f8a4d4d7ac62e203.jpg',
#  'data/obj/f8a55709dab3cc17.jpg',
#  'data/obj/f8a826d842acc5fa.jpg',
#  'data/obj/f8a85c0046e8241e.jpg',
#  'data/obj/f8a962d748ce175c.jpg',
#  'data/obj/f8a9fb33a958a185.jpg',
#  'data/obj/f8ad59a226c03a27.jpg',
#  'data/obj/f8b5dc27cf06d529.jpg',
#  'data/obj/f8b5e2f5f574f143.jpg',
#  'data/obj/f8b6f53cb717d6e7.jpg',
#  'data/obj/f8b981edd2b635fc.jpg',
#  'data/obj/f8ba19ae3ad5fe6b.jpg',
#  'data/obj/f8baebeaa176b348.jpg',
#  'data/obj/f8bc2afbd59e730a.jpg',
#  'data/obj/f8bcb207ed58e462.jpg',
#  'data/obj/f8bcea4e7e2e1dfb.jpg',
#  'data/obj/f8c136b4c754e247.jpg',
#  'data/obj/f8c26878ce1be2bb.jpg',
#  'data/obj/f8c59419ef935e9a.jpg',
#  'data/obj/f8ca2fab23e1db8a.jpg',
#  'data/obj/f8cc7f6346cc4884.jpg',
#  'data/obj/f8ccaca105964605.jpg',
#  'data/obj/f8ceb4a57e1ad021.jpg',
#  'data/obj/f8d06bdc48659474.jpg',
#  'data/obj/f8d33a4b4b25de19.jpg',
#  'data/obj/f8d62b82b4fc8abc.jpg',
#  'data/obj/f8d707418eb8d333.jpg',
#  'data/obj/f8d7a49f5b61c14d.jpg',
#  'data/obj/f8d9fa31109376b6.jpg',
#  'data/obj/f8da540a22cb55e2.jpg',
#  'data/obj/f8da9de01972f7f7.jpg',
#  'data/obj/f8db42beb16eeb44.jpg',
#  'data/obj/f8dc94befc6cbf51.jpg',
#  'data/obj/f8dcfef1a0c5e7f3.jpg',
#  'data/obj/f8de2ee52edb18a1.jpg',
#  'data/obj/f8de6973405208ae.jpg',
#  'data/obj/f8deeb7e8980ac27.jpg',
#  'data/obj/f8e0edc1d5caf7db.jpg',
#  'data/obj/f8e47635379eadf5.jpg',
#  'data/obj/f8e7818974e1364d.jpg',
#  'data/obj/f8ec6a3341f430e1.jpg',
#  'data/obj/f8ee52843e422849.jpg',
#  'data/obj/f8ef7d15c0c25b09.jpg',
#  'data/obj/f8f48eb830282669.jpg',
#  'data/obj/f8f9225acfaa0c14.jpg',
#  'data/obj/f8fbd79ed42ac7cc.jpg',
#  'data/obj/f8fbe4e9a7895931.jpg',
#  'data/obj/f8fdab99796121a8.jpg',
#  'data/obj/f8fe9ffe0b308d81.jpg',
#  'data/obj/f901a9f96288659c.jpg',
#  'data/obj/f907bf0b010f7d1f.jpg',
#  'data/obj/f90969cc80664516.jpg',
#  'data/obj/f90b86ea85a62a4d.jpg',
#  'data/obj/f90c5ef97644677d.jpg',
#  'data/obj/f90cf8db7c3961f9.jpg',
#  'data/obj/f90d02da7768adcd.jpg',
#  'data/obj/f90d0d2f536e36b2.jpg',
#  'data/obj/f90eed4fc7037bce.jpg',
#  'data/obj/f91257b144e1129f.jpg',
#  'data/obj/f912ec5150cf991c.jpg',
#  'data/obj/f916c68e871652a8.jpg',
#  'data/obj/f918d4b7a4766839.jpg',
#  'data/obj/f918edbcb6c27053.jpg',
#  'data/obj/f91a841e39eb9027.jpg',
#  'data/obj/f91c573b84f155a3.jpg',
#  'data/obj/f920d747afbe9cad.jpg',
#  'data/obj/f922fcc5b1418897.jpg',
#  'data/obj/f9243647c7352b4a.jpg',
#  'data/obj/f931a87aca5630a9.jpg',
#  'data/obj/f93507109a20bd10.jpg',
#  'data/obj/f936d10adac44a68.jpg',
#  'data/obj/f938b7ac9c8c0583.jpg',
#  'data/obj/f93a3fa3fe2894f6.jpg',
#  'data/obj/f93b86ae80356b9a.jpg',
#  'data/obj/f93e2561dea5b8d8.jpg',
#  'data/obj/f93ef6289f7acf20.jpg',
#  'data/obj/f93ff608b1c6bee5.jpg',
#  'data/obj/f9455349caecee55.jpg',
#  'data/obj/f946ccffaf948311.jpg',
#  'data/obj/f9487eea0e1ccd11.jpg',
#  'data/obj/f9491d2c1c5fbe9d.jpg',
#  'data/obj/f94a033c24d3a8f4.jpg',
#  'data/obj/f94b05444e2eeb7f.jpg',
#  'data/obj/f95586b3d3af850b.jpg',
#  'data/obj/f955cd8e7d8aeca3.jpg',
#  'data/obj/f957fdc44594206c.jpg',
#  'data/obj/f95913deddece63f.jpg',
#  'data/obj/f9593488ce69289c.jpg',
#  'data/obj/f95a317265abbb07.jpg',
#  'data/obj/f95b4cd76623aaac.jpg',
#  'data/obj/f95c32f2ae2775b1.jpg',
#  'data/obj/f95c81225334d1ac.jpg',
#  'data/obj/f95eeb841cc0c57c.jpg',
#  'data/obj/f963f9e0cb2f08f2.jpg',
#  'data/obj/f964256d8f6313b8.jpg',
#  'data/obj/f96662acd7b2cce1.jpg',
#  'data/obj/f967afa925b9b94a.jpg',
#  'data/obj/f96bcd5917ba05ee.jpg',
#  'data/obj/f96d1d331ca4a783.jpg',
#  'data/obj/f96efb59809c4f2b.jpg',
#  'data/obj/f96f26defb7ef704.jpg',
#  'data/obj/f9710ef393fdebae.jpg',
#  'data/obj/f9731315ac2b591d.jpg',
#  'data/obj/f97366d809e9202a.jpg',
#  'data/obj/f975a42d633e0363.jpg',
#  'data/obj/f975ae6fbfe2742a.jpg',
#  'data/obj/f975f8aaac5f2c70.jpg',
#  'data/obj/f97a66e325595b11.jpg',
#  'data/obj/f97da12e714120d0.jpg',
#  'data/obj/f97f2539529f8e19.jpg',
#  'data/obj/f97f4be87d321db5.jpg',
#  'data/obj/f981e3583afade16.jpg',
#  'data/obj/f982cffecc118878.jpg',
#  'data/obj/f985881b86ac08b8.jpg',
#  'data/obj/f9859a1f2d1c0e95.jpg',
#  'data/obj/f987698b7627c757.jpg',
#  'data/obj/f98be4a55b572c70.jpg',
#  'data/obj/f98f5b24f8b8c895.jpg',
#  'data/obj/f994f86008597b46.jpg',
#  'data/obj/f99652add53b3895.jpg',
#  'data/obj/f99b291ab93e1aac.jpg',
#  'data/obj/f9a4e9835f460d1c.jpg',
#  'data/obj/f9aa0656e840f4eb.jpg',
#  'data/obj/f9aa29a0e2ea6f25.jpg',
#  'data/obj/f9ad9d5c378463de.jpg',
#  'data/obj/f9ae5eed320dcbf6.jpg',
#  'data/obj/f9afb74210832083.jpg',
#  'data/obj/f9b0f1a402b5e57a.jpg',
#  'data/obj/f9b4db2082054233.jpg',
#  'data/obj/f9b68d75dd6776d5.jpg',
#  'data/obj/f9b7191018ac1398.jpg',
#  'data/obj/f9b798ce0d13517a.jpg',
#  'data/obj/f9b87bcb10359fa2.jpg',
#  'data/obj/f9b88b1d6f54628f.jpg',
#  'data/obj/f9b9125918538da3.jpg',
#  'data/obj/f9b9d2d9c5424c37.jpg',
#  'data/obj/f9bbdd8802c2baa9.jpg',
#  'data/obj/f9bd5a2fff34c9c7.jpg',
#  'data/obj/f9bec2acb776e004.jpg',
#  'data/obj/f9c0c5c22a9a4789.jpg',
#  'data/obj/f9c50bdd8ed4ff3a.jpg',
#  'data/obj/f9c6713f1df62b49.jpg',
#  'data/obj/f9cb7a788fff3ac8.jpg',
#  'data/obj/f9cdc7b61957c3e5.jpg',
#  'data/obj/f9ce749c9b33afe7.jpg',
#  'data/obj/f9cf5d60a2adb19e.jpg',
#  'data/obj/f9cfbb04c641b63d.jpg',
#  'data/obj/f9d0b51fcf5dcd6a.jpg',
#  'data/obj/f9d0c6a2671e1e80.jpg',
#  'data/obj/f9d229ad932af39e.jpg',
#  'data/obj/f9d34af7c43c26cd.jpg',
#  'data/obj/f9d53990c835f94b.jpg',
#  'data/obj/f9d561b42675c960.jpg',
#  'data/obj/f9daa177483d10e7.jpg',
#  'data/obj/f9dae6af54c9002a.jpg',
#  'data/obj/f9db6fe6fe47ed57.jpg',
#  'data/obj/f9dd91e7466b2ca0.jpg',
#  'data/obj/f9de92df0e4ddab7.jpg',
#  'data/obj/f9dfd7e11fecfa35.jpg',
#  'data/obj/f9e0c9022728fac3.jpg',
#  'data/obj/f9e132dfcc3dd7c6.jpg',
#  'data/obj/f9e3766a214e0561.jpg',
#  'data/obj/f9e66ea99426b390.jpg',
#  'data/obj/f9eb2cfc44c5ee6a.jpg',
#  'data/obj/f9ed1fef5acd9206.jpg',
#  'data/obj/f9f3fd9e969d40a1.jpg',
#  'data/obj/f9f424da8ed5dac4.jpg',
#  'data/obj/f9f87b6406bd4e3f.jpg',
#  'data/obj/f9f8e136720ca370.jpg',
#  'data/obj/f9fa9df2126dbf82.jpg',
#  'data/obj/f9fc57675de3ec8a.jpg',
#  'data/obj/f9fd4adb33726771.jpg',
#  'data/obj/fa0120c17df5bbe1.jpg',
#  'data/obj/fa01678b10be3ac3.jpg',
#  'data/obj/fa01dd057eb9ee5f.jpg',
#  'data/obj/fa02854000b21510.jpg',
#  'data/obj/fa06ecf2deed2c7d.jpg',
#  'data/obj/fa0b60122e557d48.jpg',
#  'data/obj/fa0c04a8cd99571a.jpg',
#  'data/obj/fa0ea33b9963175a.jpg',
#  'data/obj/fa0ee4311576d7e7.jpg',
#  'data/obj/fa13d40faeb96694.jpg',
#  'data/obj/fa14c4a392e77ba5.jpg',
#  'data/obj/fa16aaa6858cf61b.jpg',
#  'data/obj/fa176c10ff1eb177.jpg',
#  'data/obj/fa1773e887aa3cbf.jpg',
#  'data/obj/fa17be034125279b.jpg',
#  'data/obj/fa18b06f8247b82f.jpg',
#  'data/obj/fa1dba9eea3cbd33.jpg',
#  'data/obj/fa1e349a2e54ed13.jpg',
#  'data/obj/fa1e5c7955d92841.jpg',
#  'data/obj/fa24d1829b5f26e6.jpg',
#  'data/obj/fa251bae925184be.jpg',
#  'data/obj/fa2a998a4a2a67db.jpg',
#  'data/obj/fa2b9cdcbfd5c2d3.jpg',
#  'data/obj/fa2e72aba811c3e6.jpg',
#  'data/obj/fa31a682c2fe6616.jpg',
#  'data/obj/fa34aa5183ff41e9.jpg',
#  'data/obj/fa34d296a93339a1.jpg',
#  'data/obj/fa39ce6d9a1d775f.jpg',
#  'data/obj/fa3a24bf75e000ab.jpg',
#  'data/obj/fa3ab2fbd9004444.jpg',
#  'data/obj/fa3ab70876d4eebe.jpg',
#  'data/obj/fa416ae4ae506a48.jpg',
#  'data/obj/fa4256f32064ec9e.jpg',
#  'data/obj/fa42a2c97e3a00d8.jpg',
#  'data/obj/fa43c56203aa1c41.jpg',
#  'data/obj/fa43d57d2f1e9867.jpg',
#  'data/obj/fa44d783bb5a38e8.jpg',
#  'data/obj/fa47369ce773924e.jpg',
#  'data/obj/fa4937be2ecd88d7.jpg',
#  'data/obj/fa4986136f67831a.jpg',
#  'data/obj/fa4a35fcbbecdcae.jpg',
#  'data/obj/fa4b4792c2ac9d1b.jpg',
#  'data/obj/fa4c4c048741578b.jpg',
#  'data/obj/fa517165687477b5.jpg',
#  'data/obj/fa549ab7864eb026.jpg',
#  'data/obj/fa558d6b1b94d0a8.jpg',
#  'data/obj/fa56710e1e7f65ca.jpg',
#  'data/obj/fa56dffe45186412.jpg',
#  'data/obj/fa575deb3847adce.jpg',
#  'data/obj/fa5a56d2ba5ee0b4.jpg',
#  'data/obj/fa5a6f1fa66b2823.jpg',
#  'data/obj/fa5b8b24d71ffc4f.jpg',
#  'data/obj/fa5f1e570280e1d6.jpg',
#  'data/obj/fa602fc917a6a65a.jpg',
#  'data/obj/fa619f3277a4cbea.jpg',
#  'data/obj/fa64df1cb45846a6.jpg',
#  'data/obj/fa64f774e3dbe4e8.jpg',
#  'data/obj/fa66d29c2e512f07.jpg',
#  'data/obj/fa6713bc80a25a06.jpg',
#  'data/obj/fa69a94fe51e532f.jpg',
#  'data/obj/fa6c3f5cea13e400.jpg',
#  'data/obj/fa6c504be20d02e0.jpg',
#  'data/obj/fa6c70254bcee54d.jpg',
#  'data/obj/fa6f093933681904.jpg',
#  'data/obj/fa6ff20fe2635706.jpg',
#  'data/obj/fa71ac9cff311e4b.jpg',
#  'data/obj/fa73e0117103f81b.jpg',
#  'data/obj/fa75406265a725c8.jpg',
#  'data/obj/fa762801d6e7ec2b.jpg',
#  'data/obj/fa7da810e2d5a635.jpg',
#  'data/obj/fa7f7049829e1f8c.jpg',
#  'data/obj/fa840a8bf494c7c3.jpg',
#  'data/obj/fa855e59fbd85f10.jpg',
#  'data/obj/fa870501b0f500a0.jpg',
#  'data/obj/fa88a5cd65a18658.jpg',
#  'data/obj/fa88b51c209fa8ab.jpg',
#  'data/obj/fa8bd39c26014245.jpg',
#  'data/obj/fa8d822dc7656f08.jpg',
#  'data/obj/fa8f296a2fff709b.jpg',
#  'data/obj/fa980860b239af79.jpg',
#  'data/obj/fa98776d1d3b08d4.jpg',
#  'data/obj/fa9b9a23217969d5.jpg',
#  'data/obj/fa9d2c8a95dd360d.jpg',
#  'data/obj/fa9d950565d30ede.jpg',
#  'data/obj/faa37fd57ae99adf.jpg',
#  'data/obj/faa5291a2aae11ae.jpg',
#  'data/obj/faa8f480c2ba00db.jpg',
#  'data/obj/faa95c917ebc05e9.jpg',
#  'data/obj/faae00c1720b2b14.jpg',
#  'data/obj/fab04a1afcd5090a.jpg',
#  'data/obj/fab153f50c18fd08.jpg',
#  'data/obj/fab15679f8468079.jpg',
#  'data/obj/fab1f8a51b75b1bf.jpg',
#  'data/obj/fab266555d53fc48.jpg',
#  'data/obj/fab636bbe0ea4d5d.jpg',
#  'data/obj/fab855056e950b2c.jpg',
#  'data/obj/fab9f2a04904d569.jpg',
#  'data/obj/fabaa82e762e8c36.jpg',
#  'data/obj/fabb5a662500398c.jpg',
#  'data/obj/fabde66f307b9934.jpg',
#  'data/obj/faca0b53d8b7bfe8.jpg',
#  'data/obj/faca56f3ccfe8b2f.jpg',
#  'data/obj/facaac570a4c7b93.jpg',
#  'data/obj/facba7d1baebd3fb.jpg',
#  'data/obj/facccec7b5ead06c.jpg',
#  'data/obj/facd9cff139a4c79.jpg',
#  'data/obj/fad24108a6fad9f6.jpg',
#  'data/obj/fad2ba674a954e0c.jpg',
#  'data/obj/fad4820abedc0249.jpg',
#  'data/obj/fad4885be49c3aaa.jpg',
#  'data/obj/fad710908cca50c8.jpg',
#  'data/obj/fad7c558dd6b84f1.jpg',
#  'data/obj/fad86b329b4a5e61.jpg',
#  'data/obj/fad88eaba20a6338.jpg',
#  'data/obj/fad9b15c38d40c5e.jpg',
#  'data/obj/fad9bc5d711c3226.jpg',
#  'data/obj/fadbb15420bb6b2a.jpg',
#  'data/obj/fade5ce4af6b2d5b.jpg',
#  'data/obj/fadee5ce6af303f6.jpg',
#  'data/obj/fae034aa690a3a99.jpg',
#  'data/obj/fae3749eb42a0b83.jpg',
#  'data/obj/fae3e86405d4cbea.jpg',
#  'data/obj/fae6655ad49bba62.jpg',
#  'data/obj/fae964da29bed538.jpg',
#  'data/obj/faea34b635c609e1.jpg',
#  'data/obj/faeed8f3f3cc7f0b.jpg',
#  'data/obj/faef7db53d79fe18.jpg',
#  'data/obj/faeffcb95c312bdb.jpg',
#  'data/obj/faf002de0dc113c3.jpg',
#  'data/obj/faf26f71f56b6cdf.jpg',
#  'data/obj/faf8017daa932804.jpg',
#  'data/obj/fafe2ff27b7836bd.jpg',
#  'data/obj/fafe6620c27d83c0.jpg',
#  'data/obj/fb02a485ec8ca24c.jpg',
#  'data/obj/fb03103102672d24.jpg',
#  'data/obj/fb03617b60d39dc5.jpg',
#  'data/obj/fb038e19f6d9090b.jpg',
#  'data/obj/fb083ff5a4b33195.jpg',
#  'data/obj/fb08f7ba749458c1.jpg',
#  'data/obj/fb0a1b073b203ba1.jpg',
#  'data/obj/fb0bdf0d9d95989a.jpg',
#  'data/obj/fb100aa2861de743.jpg',
#  'data/obj/fb102b3acff02479.jpg',
#  'data/obj/fb12c222b984d771.jpg',
#  'data/obj/fb132e4515650d6b.jpg',
#  'data/obj/fb14cb50a446650b.jpg',
#  'data/obj/fb191856a615477b.jpg',
#  'data/obj/fb1c241aa210887e.jpg',
#  'data/obj/fb1ffd8470c37ec0.jpg',
#  'data/obj/fb226ea80bec3242.jpg',
#  'data/obj/fb22979272830222.jpg',
#  'data/obj/fb22c172ec8e16a0.jpg',
#  'data/obj/fb24411fe1924118.jpg',
#  'data/obj/fb2ac8d633e4c8d0.jpg',
#  'data/obj/fb2e2eeafe59dcf5.jpg',
#  'data/obj/fb312a11ead0b8e1.jpg',
#  'data/obj/fb37db9f82049c66.jpg',
#  'data/obj/fb38c648509b237a.jpg',
#  'data/obj/fb39777dce49609c.jpg',
#  'data/obj/fb3afef23d779a7b.jpg',
#  'data/obj/fb3bc91003256403.jpg',
#  'data/obj/fb3e15b135ae0d80.jpg',
#  'data/obj/fb40481b12874363.jpg',
#  'data/obj/fb40b604e1984298.jpg',
#  'data/obj/fb41642db8817232.jpg',
#  'data/obj/fb418d0791063ea3.jpg',
#  'data/obj/fb46759421baddb8.jpg',
#  'data/obj/fb4700f8a9e501ce.jpg',
#  'data/obj/fb47b43b7b60b07c.jpg',
#  'data/obj/fb47c23233feb3f3.jpg',
#  'data/obj/fb4e0486e8cb7322.jpg',
#  'data/obj/fb5020037efb8278.jpg',
#  'data/obj/fb5124af57ac730a.jpg',
#  'data/obj/fb52c6605698f7cf.jpg',
#  'data/obj/fb533e13dc09801e.jpg',
#  'data/obj/fb53bbfcb1bb78b7.jpg',
#  'data/obj/fb56492f5b208092.jpg',
#  'data/obj/fb580ac96f053931.jpg',
#  'data/obj/fb58a3e18f3dca08.jpg',
#  'data/obj/fb5a41f8783a8e52.jpg',
#  'data/obj/fb5b8ab32f770edc.jpg',
#  'data/obj/fb681e2b187c6a81.jpg',
#  'data/obj/fb697e1a442d9f53.jpg',
#  'data/obj/fb69dc171ffbee82.jpg',
#  'data/obj/fb6a30e5e9a098aa.jpg',
#  'data/obj/fb6ad077f80b4692.jpg',
#  'data/obj/fb6b5196d8345f36.jpg',
#  'data/obj/fb6c181d222e50d4.jpg',
#  'data/obj/fb6cae1af17f39c0.jpg',
#  'data/obj/fb6ed02e6f503def.jpg',
#  'data/obj/fb71873df3d8365a.jpg',
#  'data/obj/fb7ab9de8905d2d2.jpg',
#  'data/obj/fb8558bca52af76d.jpg',
#  'data/obj/fb8bdc55b847bd22.jpg',
#  'data/obj/fb8d96c699834eb9.jpg',
#  'data/obj/fb8eae91ea6bad10.jpg',
#  'data/obj/fb9065576a70e1ca.jpg',
#  'data/obj/fb90cb88780f4da3.jpg',
#  'data/obj/fb93f7847b90dddf.jpg',
#  'data/obj/fb94faab2e7f868a.jpg',
#  'data/obj/fb9a11c13272930b.jpg',
#  'data/obj/fb9d0a4e3fcd750c.jpg',
#  'data/obj/fba0702cca2b8f53.jpg',
#  'data/obj/fba0fd3961cd4475.jpg',
#  'data/obj/fba1a911e18643a6.jpg',
#  'data/obj/fba48dded9870c4c.jpg',
#  'data/obj/fba5f8ca3150d44a.jpg',
#  'data/obj/fba6941de0b90bdc.jpg',
#  'data/obj/fbae164319c5e1f9.jpg',
#  'data/obj/fbb08e71eba746eb.jpg',
#  'data/obj/fbb113d2c88c9a07.jpg',
#  'data/obj/fbb35f940978b28a.jpg',
#  'data/obj/fbb43b2a46fb22e8.jpg',
#  'data/obj/fbb65807c0887db2.jpg',
#  'data/obj/fbc25b5cb62c0443.jpg',
#  'data/obj/fbc3c3708ee68e28.jpg',
#  'data/obj/fbc66e816cf180ea.jpg',
#  'data/obj/fbc752c89e42001b.jpg',
#  'data/obj/fbc9e3b163aee158.jpg',
#  'data/obj/fbc9fc05c35ce4d4.jpg',
#  'data/obj/fbcc78d766c09c06.jpg',
#  'data/obj/fbce2044fe0da894.jpg',
#  'data/obj/fbce8e9e32d7d6cf.jpg',
#  'data/obj/fbd415629a0bcba3.jpg',
#  'data/obj/fbd59d11de71e8d6.jpg',
#  'data/obj/fbd8773df835298d.jpg',
#  'data/obj/fbdbfa1cfba03b2b.jpg',
#  'data/obj/fbdf62855ecbe601.jpg',
#  'data/obj/fbdfe1e33ec61c97.jpg',
#  'data/obj/fbe11012f6583ed4.jpg',
#  'data/obj/fbe25c4d747d722e.jpg',
#  'data/obj/fbe2a7facb68283a.jpg',
#  'data/obj/fbe8f033539c8a5a.jpg',
#  'data/obj/fbe939e3866dc8ee.jpg',
#  'data/obj/fbea8ac773acfd1a.jpg',
#  'data/obj/fbedd6bb14e48cf6.jpg',
#  'data/obj/fbefa625b8aa8cfe.jpg',
#  'data/obj/fbf1604a4e2aee9c.jpg',
#  'data/obj/fbf30a363208eeb3.jpg',
#  'data/obj/fbf348f844033d85.jpg',
#  'data/obj/fbf61f5bc6005cf3.jpg',
#  'data/obj/fbf7cdca6c8eb9d5.jpg',
#  'data/obj/fbf88951e126898a.jpg',
#  'data/obj/fbf9b78f385e687e.jpg',
#  'data/obj/fbf9b834f261fa8c.jpg',
#  'data/obj/fbfc1cea00946c12.jpg',
#  'data/obj/fbfd8bd444b281d1.jpg',
#  'data/obj/fbfe9c2805cd39df.jpg',
#  'data/obj/fc01fee8cd9d2a77.jpg',
#  'data/obj/fc04d058f4cc9623.jpg',
#  'data/obj/fc07d630b32b9945.jpg',
#  'data/obj/fc0a9d739ee46b35.jpg',
#  'data/obj/fc0af60d1b47a0d6.jpg',
#  'data/obj/fc0ffef14c6965b6.jpg',
#  'data/obj/fc1240c55961a676.jpg',
#  'data/obj/fc12503ff15fabf6.jpg',
#  'data/obj/fc1259e0134877ef.jpg',
#  'data/obj/fc12ef9c929e8f88.jpg',
#  'data/obj/fc1747c400e5b6e7.jpg',
#  'data/obj/fc18a900f4ede6e3.jpg',
#  'data/obj/fc1aaa8bce704e83.jpg',
#  'data/obj/fc1c0083c5ab506c.jpg',
#  'data/obj/fc252ece917fdba9.jpg',
#  'data/obj/fc269c00d9f96367.jpg',
#  'data/obj/fc2792a289aee555.jpg',
#  'data/obj/fc28adf2f4379726.jpg',
#  'data/obj/fc2a5eeb613e1f0b.jpg',
#  'data/obj/fc2c2cfcda754591.jpg',
#  'data/obj/fc2d6132d3d7feba.jpg',
#  'data/obj/fc2d74b3224979c4.jpg',
#  'data/obj/fc2ef3f09d9e2302.jpg',
#  'data/obj/fc2fc968386bbb25.jpg',
#  'data/obj/fc2fd7c2dba0c360.jpg',
#  'data/obj/fc3003ec1cdeb0cf.jpg',
#  'data/obj/fc301d5e17a251e7.jpg',
#  'data/obj/fc3069002ae1959d.jpg',
#  'data/obj/fc3159fcb63efd39.jpg',
#  'data/obj/fc31d68b563e2a47.jpg',
#  'data/obj/fc33f009120070dd.jpg',
#  'data/obj/fc3763c2aba2fbe9.jpg',
#  'data/obj/fc37fbd8ca36c10e.jpg',
#  'data/obj/fc38f5d490275999.jpg',
#  'data/obj/fc3ae5db5b185616.jpg',
#  'data/obj/fc3cd8efbe208688.jpg',
#  'data/obj/fc4009061fdf80e1.jpg',
#  'data/obj/fc42bc9587ff4681.jpg',
#  'data/obj/fc4428fdc0872946.jpg',
#  'data/obj/fc44dc62037dacb0.jpg',
#  'data/obj/fc49e9ffb49c05d4.jpg',
#  'data/obj/fc4cbc60475ffc2c.jpg',
#  'data/obj/fc4fb3013e2fda81.jpg',
#  'data/obj/fc5180c778e796f0.jpg',
#  'data/obj/fc5188b5dc12a007.jpg',
#  'data/obj/fc51e07542d1c774.jpg',
#  'data/obj/fc522934012040c5.jpg',
#  'data/obj/fc53a55fa2309ad6.jpg',
#  'data/obj/fc549c0a7d87213c.jpg',
#  'data/obj/fc550b986507dbd7.jpg',
#  'data/obj/fc5525f94529a0c6.jpg',
#  'data/obj/fc5b55ec832bb1cd.jpg',
#  'data/obj/fc5dcebeb6a36e3a.jpg',
#  'data/obj/fc5e3874e3932d95.jpg',
#  'data/obj/fc5fa3425c7893bf.jpg',
#  'data/obj/fc5fe87d6dca488f.jpg',
#  'data/obj/fc61f1e4acee2554.jpg',
#  'data/obj/fc63fc8b0dc69166.jpg',
#  'data/obj/fc64020b35d6b21d.jpg',
#  'data/obj/fc64049066d3878c.jpg',
#  'data/obj/fc66cbb80e91a46e.jpg',
#  'data/obj/fc6756124100dc11.jpg',
#  'data/obj/fc6960eb74f75206.jpg',
#  'data/obj/fc69a0dc7c1fcb2a.jpg',
#  'data/obj/fc6c798c4d1b4919.jpg',
#  'data/obj/fc6cd7addaabf1d2.jpg',
#  'data/obj/fc6f319728f88a81.jpg',
#  'data/obj/fc70973681dc4eea.jpg',
#  'data/obj/fc72f81edb37e126.jpg',
#  'data/obj/fc73c18b03042d8f.jpg',
#  'data/obj/fc76d4fb4611f0f5.jpg',
#  'data/obj/fc7ac32a815d9b28.jpg',
#  'data/obj/fc7adcb9f7948352.jpg',
#  'data/obj/fc7c4461b5a8fc51.jpg',
#  'data/obj/fc7cd34c20ba6fc7.jpg',
#  'data/obj/fc8492a725c9c6f0.jpg',
#  'data/obj/fc86993e1433dd90.jpg',
#  'data/obj/fc887b1d913a21fc.jpg',
#  'data/obj/fc8c9046c4c55b46.jpg',
#  'data/obj/fc8d8274c4781ffd.jpg',
#  'data/obj/fc8fd8641572853d.jpg',
#  'data/obj/fc90fc0bc43d1ba7.jpg',
#  'data/obj/fc91fa8422713319.jpg',
#  'data/obj/fc98d646347076ae.jpg',
#  'data/obj/fc9a0c0292e8f781.jpg',
#  'data/obj/fc9a68d8c5d5a4c8.jpg',
#  'data/obj/fc9adb4cdd1cebe9.jpg',
#  'data/obj/fc9cf4756fea65b1.jpg',
#  'data/obj/fc9daeb8319d7c24.jpg',
#  'data/obj/fca0408e35458da3.jpg',
#  'data/obj/fca0429592ea82ef.jpg',
#  'data/obj/fca27a6b96b9ad5c.jpg',
#  'data/obj/fca7c044ea2b6466.jpg',
#  'data/obj/fca802b7385ba18c.jpg',
#  'data/obj/fca8fd398332e9f7.jpg',
#  'data/obj/fcaa6361766e4c16.jpg',
#  'data/obj/fcb41533f7efb547.jpg',
#  'data/obj/fcb4c09fcad53c4e.jpg',
#  'data/obj/fcbaf9f4c263ff41.jpg',
#  'data/obj/fcbbea39ae26bd5e.jpg',
#  'data/obj/fcbc3391839ab8f8.jpg',
#  'data/obj/fcbf3dc6287773f4.jpg',
#  'data/obj/fcc095a5e5d1877f.jpg',
#  'data/obj/fcc54ada07986e1e.jpg',
#  'data/obj/fcc648f11bf570fd.jpg',
#  'data/obj/fcc99f3b52a13547.jpg',
#  'data/obj/fcca050aa7f350f3.jpg',
#  'data/obj/fccb0de6fac455e6.jpg',
#  'data/obj/fccbdc06154936c4.jpg',
#  'data/obj/fcccd9ad7d3ac9c7.jpg',
#  'data/obj/fccd8ffe837fd6cb.jpg',
#  'data/obj/fcce303d067beaf0.jpg',
#  'data/obj/fcce9487cab235c2.jpg',
#  'data/obj/fcd0290522babdca.jpg',
#  'data/obj/fcd0b591beb0efd7.jpg',
#  'data/obj/fcd213f95e9a334a.jpg',
#  'data/obj/fcd6fb01c7d0d18c.jpg',
#  'data/obj/fcd8afe8b09d0a44.jpg',
#  'data/obj/fcda00eed2563a25.jpg',
#  'data/obj/fcdb0a0d2ad923a7.jpg',
#  'data/obj/fcdd11da7ebf0f4e.jpg',
#  'data/obj/fce3816614ad92b4.jpg',
#  'data/obj/fce8036ac261dc66.jpg',
#  'data/obj/fced01aff0784339.jpg',
#  'data/obj/fcef718d759e43eb.jpg',
#  'data/obj/fcf258700345ad63.jpg',
#  'data/obj/fcf2c36984a935ac.jpg',
#  'data/obj/fcf3b51aaa57a2e3.jpg',
#  'data/obj/fcf4381e9ef26bb8.jpg',
#  'data/obj/fcf6bce93b8fddaa.jpg',
#  'data/obj/fcf6dcc1109cc388.jpg',
#  'data/obj/fcfe934a0ec51fe7.jpg',
#  'data/obj/fd014b96e38aa24f.jpg',
#  'data/obj/fd0210e876adc5ab.jpg',
#  'data/obj/fd058e52fe5204e2.jpg',
#  'data/obj/fd05eaf5bf9b0a87.jpg',
#  'data/obj/fd0ed2ead09b1550.jpg',
#  'data/obj/fd11589e66f944a2.jpg',
#  'data/obj/fd1161445d4256b6.jpg',
#  'data/obj/fd1274c9eea38e9e.jpg',
#  'data/obj/fd19aab2a5635011.jpg',
#  'data/obj/fd21b230ef7aeb2f.jpg',
#  'data/obj/fd28e4d24f966c08.jpg',
#  'data/obj/fd290fc677dabc1d.jpg',
#  'data/obj/fd292544a935a4ee.jpg',
#  'data/obj/fd2933594244765b.jpg',
#  'data/obj/fd2bd62d80100d7a.jpg',
#  'data/obj/fd30c31b7a56505f.jpg',
#  'data/obj/fd3371ca79da77d7.jpg',
#  'data/obj/fd3541cdad67b140.jpg',
#  'data/obj/fd36734ff20f86b5.jpg',
#  'data/obj/fd3b5c696f531a9b.jpg',
#  'data/obj/fd42d5b11425bf3a.jpg',
#  'data/obj/fd49ed286b613573.jpg',
#  'data/obj/fd4c1a22fd21e50a.jpg',
#  'data/obj/fd54681afc923884.jpg',
#  'data/obj/fd57e1d4a51ca8bc.jpg',
#  'data/obj/fd59e202f827aa5b.jpg',
#  'data/obj/fd5dd74497e39501.jpg',
#  'data/obj/fd604c7d95537b85.jpg',
#  'data/obj/fd60d1218a1d422b.jpg',
#  'data/obj/fd656c41192b4c10.jpg',
#  'data/obj/fd689255d50cd406.jpg',
#  'data/obj/fd6bbc8303317487.jpg',
#  'data/obj/fd71f8068a65ec9e.jpg',
#  'data/obj/fd72fd60d9dd0ac9.jpg',
#  'data/obj/fd75b0395ca9ed62.jpg',
#  'data/obj/fd77871767a857cc.jpg',
#  'data/obj/fd77c1fa5a8782a5.jpg',
#  'data/obj/fd7966920143221e.jpg',
#  'data/obj/fd7c7b6ad642a6a0.jpg',
#  'data/obj/fd7d15bef5d49286.jpg',
#  'data/obj/fd7d1a1ee27c252a.jpg',
#  'data/obj/fd7e844a4c81bc7d.jpg',
#  'data/obj/fd7f02293d21cedb.jpg',
#  'data/obj/fd82abd5ac4bb89a.jpg',
#  'data/obj/fd8323da5b32bda1.jpg',
#  'data/obj/fd84a9c03fab1b89.jpg',
#  'data/obj/fd85f019d367dc3c.jpg',
#  'data/obj/fd85fa60d52a682c.jpg',
#  'data/obj/fd8873bcf9dcfa18.jpg',
#  'data/obj/fd8c5ca73a7e0fe7.jpg',
#  'data/obj/fd8c66ae2bb86ef3.jpg',
#  'data/obj/fd8d669f950f0aad.jpg',
#  'data/obj/fd91372403c0c735.jpg',
#  'data/obj/fd91e8b834e3a6c0.jpg',
#  'data/obj/fd93394fb96920af.jpg',
#  'data/obj/fd95ecb3f1e97ea7.jpg',
#  'data/obj/fd966d5352d1b691.jpg',
#  'data/obj/fd9a158a8371d09f.jpg',
#  'data/obj/fd9ad24339559f12.jpg',
#  'data/obj/fd9dc73a5b3fec30.jpg',
#  'data/obj/fda1d773da1b18e8.jpg',
#  'data/obj/fda487d97f52f599.jpg',
#  'data/obj/fda49d43738caf56.jpg',
#  'data/obj/fda5105b0df8bd9c.jpg',
#  'data/obj/fda554b351a078d8.jpg',
#  'data/obj/fda85e4491255cd5.jpg',
#  'data/obj/fdaa44ecc61477b5.jpg',
#  'data/obj/fdaa68c427098926.jpg',
#  'data/obj/fdac3b5c37de58cb.jpg',
#  'data/obj/fdac73f71655693d.jpg',
#  'data/obj/fdaf3cd1a7295465.jpg',
#  'data/obj/fdb02f1cbb509aa8.jpg',
#  'data/obj/fdb1aaabb984481b.jpg',
#  'data/obj/fdb2510ef417120d.jpg',
#  'data/obj/fdb2bddf96387543.jpg',
#  'data/obj/fdb321dc4f5229cd.jpg',
#  'data/obj/fdb32dd127e50c9e.jpg',
#  'data/obj/fdb3af9b754e3f98.jpg',
#  'data/obj/fdb9b27dcaa23ad7.jpg',
#  'data/obj/fdbafafe97ee8da5.jpg',
#  'data/obj/fdbbbdb0006d831e.jpg',
#  'data/obj/fdbcb7fd8b24c0b9.jpg',
#  'data/obj/fdbd7ec291aa1c2e.jpg',
#  'data/obj/fdbdc550b04dfd3c.jpg',
#  'data/obj/fdbeb15e13bcd2d6.jpg',
#  'data/obj/fdbf70ba6ff5db05.jpg',
#  'data/obj/fdbff6055349b5a8.jpg',
#  'data/obj/fdc1789e001cb506.jpg',
#  'data/obj/fdc1bd5af957c3ca.jpg',
#  'data/obj/fdc2f3e86132a3df.jpg',
#  'data/obj/fdc8bab9c90a4fa5.jpg',
#  'data/obj/fdcccd7556ec1f72.jpg',
#  'data/obj/fdcf2ac6f72b09ba.jpg',
#  'data/obj/fdd419c97c46e8b8.jpg',
#  'data/obj/fdd7e162477d6e57.jpg',
#  'data/obj/fdd7ef6915a4ac08.jpg',
#  'data/obj/fdd98275b24aa2d4.jpg',
#  'data/obj/fdd99f63f54bc06d.jpg',
#  'data/obj/fdda11a33b41b476.jpg',
#  'data/obj/fddc1a8b636632ac.jpg',
#  'data/obj/fddcb568a11b5def.jpg',
#  'data/obj/fddcd1c5a015de90.jpg',
#  'data/obj/fdde7100b0a17dc9.jpg',
#  'data/obj/fde31476e42fbc60.jpg',
#  'data/obj/fde420f2bf03f468.jpg',
#  'data/obj/fde58c10a140d533.jpg',
#  'data/obj/fdeb10e3f2280b98.jpg',
#  'data/obj/fded62ebef690268.jpg',
#  'data/obj/fdeed1a4f31752d8.jpg',
#  'data/obj/fdf126b9f3c55c4f.jpg',
#  'data/obj/fdf148a1dae9764a.jpg',
#  'data/obj/fdf1d2766b657c37.jpg',
#  'data/obj/fdf24e0650c0312f.jpg',
#  'data/obj/fdf30251dbe2934a.jpg',
#  'data/obj/fdf3790f770b8ea2.jpg',
#  'data/obj/fdf3fc80bea89ed7.jpg',
#  'data/obj/fdf601f5dfa87fe7.jpg',
#  'data/obj/fdf67b8a86df09ad.jpg',
#  'data/obj/fdf700ca484cf758.jpg',
#  'data/obj/fdf7b628aac6d2a8.jpg',
#  'data/obj/fdfad3af54c63871.jpg',
#  'data/obj/fdff66e90d21b789.jpg',
#  'data/obj/fe001df363e0c8ce.jpg',
#  'data/obj/fe00d49cd8ee03f1.jpg',
#  'data/obj/fe0324c5b3d06d2f.jpg',
#  'data/obj/fe0acec8f30e0815.jpg',
#  'data/obj/fe0bb8e136f988b5.jpg',
#  'data/obj/fe0be99f2ecf901d.jpg',
#  'data/obj/fe0ed72faa8f241a.jpg',
#  'data/obj/fe10eb0b828af456.jpg',
#  'data/obj/fe1137b0a5f10395.jpg',
#  'data/obj/fe1303e530222b6b.jpg',
#  'data/obj/fe1346a60479c047.jpg',
#  'data/obj/fe13adf6ae6fff20.jpg',
#  'data/obj/fe18de2f90d85658.jpg',
#  'data/obj/fe1d3520abd9065d.jpg',
#  'data/obj/fe1f8ccd75b3064b.jpg',
#  'data/obj/fe22fce062cd1b0c.jpg',
#  'data/obj/fe232d6df74f0ffc.jpg',
#  'data/obj/fe26b0451ef895d8.jpg',
#  'data/obj/fe26d7b8188caf28.jpg',
#  'data/obj/fe292699fd117e06.jpg',
#  'data/obj/fe299d645e843fcb.jpg',
#  'data/obj/fe29c1741400f83c.jpg',
#  'data/obj/fe29da452b722faa.jpg',
#  'data/obj/fe2bac4810fa5bb7.jpg',
#  'data/obj/fe2d7d52b4f979e5.jpg',
#  'data/obj/fe2daed8295e47c6.jpg',
#  'data/obj/fe2e1d77be053bc7.jpg',
#  'data/obj/fe306ed4c9712078.jpg',
#  'data/obj/fe34e5a90960ac38.jpg',
#  'data/obj/fe3d4ff6554bff5c.jpg',
#  'data/obj/fe3eb595bc6fa235.jpg',
#  'data/obj/fe3fb17e44160699.jpg',
#  'data/obj/fe40e38066660575.jpg',
#  'data/obj/fe413195c0170170.jpg',
#  'data/obj/fe418c0c861fd04b.jpg',
#  'data/obj/fe4638b49c73900c.jpg',
#  'data/obj/fe47e81c7ced96d9.jpg',
#  'data/obj/fe49c13dc0c35da4.jpg',
#  'data/obj/fe4adab606e99295.jpg',
#  'data/obj/fe52b7b0237b7505.jpg',
#  'data/obj/fe5335107ddda249.jpg',
#  'data/obj/fe55a3183493e647.jpg',
#  'data/obj/fe56ff66aac6e24b.jpg',
#  'data/obj/fe572d628a675a04.jpg',
#  'data/obj/fe59d1c06983025c.jpg',
#  'data/obj/fe5a224066d0c02c.jpg',
#  'data/obj/fe5a80c3b0be80da.jpg',
#  'data/obj/fe5b28303dc4163c.jpg',
#  'data/obj/fe5d0439bddd298b.jpg',
#  'data/obj/fe5da24d01d8e8da.jpg',
#  'data/obj/fe5ffdae95fa8e2a.jpg',
#  'data/obj/fe61b38fb403bff2.jpg',
#  'data/obj/fe62427ae68dfa31.jpg',
#  'data/obj/fe65bddf0efb73ca.jpg',
#  'data/obj/fe6903c8b06ceb2b.jpg',
#  'data/obj/fe6bdc63634217cb.jpg',
#  'data/obj/fe6c316445260ec1.jpg',
#  'data/obj/fe6e7185078338ce.jpg',
#  'data/obj/fe70b3a1c598c844.jpg',
#  'data/obj/fe71c05903a55bdd.jpg',
#  'data/obj/fe7394f94701d591.jpg',
#  'data/obj/fe7417fe45c0968e.jpg',
#  'data/obj/fe75855e8190878a.jpg',
#  'data/obj/fe75e03f2573df96.jpg',
#  'data/obj/fe7784354dbd0c7b.jpg',
#  'data/obj/fe783012fdbfd128.jpg',
#  'data/obj/fe7ad23d5f502ca4.jpg',
#  'data/obj/fe7b4b68b74e01dd.jpg',
#  'data/obj/fe7b6082f5f1294d.jpg',
#  'data/obj/fe896bca348123f6.jpg',
#  'data/obj/fe8aa94039efeb5d.jpg',
#  'data/obj/fe8d15a55aa1c4bd.jpg',
#  'data/obj/fe94822e4d44bc82.jpg',
#  'data/obj/fe95df5ba60b67d3.jpg',
#  'data/obj/fe9f8ab555db507c.jpg',
#  'data/obj/fea77c1c9e0d80c8.jpg',
#  'data/obj/feaa445ac5776b56.jpg',
#  'data/obj/feaa84b0fa10f8e6.jpg',
#  'data/obj/feab235a8610105e.jpg',
#  'data/obj/feafee78275156ec.jpg',
#  'data/obj/feb4038062faf342.jpg',
#  'data/obj/feb6e5c569f06338.jpg',
#  'data/obj/feb9b196bfd86493.jpg',
#  'data/obj/feb9eccbc8a55639.jpg',
#  'data/obj/fec040987e03a1e1.jpg',
#  'data/obj/fec20bd333651fa7.jpg',
#  'data/obj/fec280f5324dd10e.jpg',
#  'data/obj/fec28bdfbb0e42a8.jpg',
#  'data/obj/fec303e08431fc21.jpg',
#  'data/obj/fec483e0284a228f.jpg',
#  'data/obj/fec59aeb50e1937a.jpg',
#  'data/obj/fec5c458e2e9b628.jpg',
#  'data/obj/fec698b4622a0156.jpg',
#  'data/obj/fec753f99a0acf33.jpg',
#  'data/obj/fec885c6bf45033e.jpg',
#  'data/obj/fecc94e20d126911.jpg',
#  'data/obj/fecd8197cc39a4bf.jpg',
#  'data/obj/fecd84ad6ff6f21b.jpg',
#  'data/obj/fecfa189fbcf77b6.jpg',
#  'data/obj/fecfe749c48ac6f4.jpg',
#  'data/obj/fecffdc75dc2747b.jpg',
#  'data/obj/fed3367dca0569c7.jpg',
#  'data/obj/fed80b7eb646d38e.jpg',
#  'data/obj/fed82012f76c56ea.jpg',
#  'data/obj/feda703653fb7ff7.jpg',
#  'data/obj/feda9a2c4d97b869.jpg',
#  'data/obj/fedae2692126db25.jpg',
#  'data/obj/fedb50fa1f65565d.jpg',
#  'data/obj/fedcee276d132975.jpg',
#  'data/obj/fedd12d64aa787c2.jpg',
#  'data/obj/fede6c2e28025ee5.jpg',
#  'data/obj/fedeb49f80fea55f.jpg',
#  'data/obj/fedeb638c0f5c149.jpg',
#  'data/obj/fedf9bdc2150b15d.jpg',
#  'data/obj/fee0d7a77e8628f5.jpg',
#  'data/obj/fee3ecd3ea7cefeb.jpg',
#  'data/obj/fee7e4c153722a9a.jpg',
#  'data/obj/fee89f61438d4490.jpg',
#  'data/obj/fee93ede0f505fa6.jpg',
#  'data/obj/feeb6ccbf2e6de3b.jpg',
#  'data/obj/feed420d6ab86d9d.jpg',
#  'data/obj/feee01bc95eff58a.jpg',
#  'data/obj/feeeafe1d3e413a6.jpg',
#  'data/obj/fef49512f71d2fb8.jpg',
#  'data/obj/fef54fd1d21c4667.jpg',
#  'data/obj/fef57328ba5004fa.jpg',
#  'data/obj/fef86819579e39f0.jpg',
#  'data/obj/fefb7ef1979b9a18.jpg',
#  'data/obj/fefbd5189d1695f7.jpg',
#  'data/obj/fefcc435fb58459e.jpg',
#  'data/obj/fefce3f5d968d596.jpg',
#  'data/obj/ff019d32f052caa1.jpg',
#  'data/obj/ff01a79340adcd85.jpg',
#  'data/obj/ff03cdc603e8d994.jpg',
#  'data/obj/ff04148777b9cfe4.jpg',
#  'data/obj/ff085f16270b528f.jpg',
#  'data/obj/ff0a8c078c09bd23.jpg',
#  'data/obj/ff0b3077756cfcd6.jpg',
#  'data/obj/ff0c5774270da9cb.jpg',
#  'data/obj/ff144e913e1dc3a1.jpg',
#  'data/obj/ff1471b3b6081817.jpg',
#  'data/obj/ff1638e91b82b392.jpg',
#  'data/obj/ff1bf781dbf7f35d.jpg',
#  'data/obj/ff2666f97e59fd71.jpg',
#  'data/obj/ff27de6f9d23aed0.jpg',
#  'data/obj/ff2890747db15d07.jpg',
#  'data/obj/ff28b825117f47ee.jpg',
#  'data/obj/ff28e1499330ca60.jpg',
#  'data/obj/ff296fe1c7fcd4a8.jpg',
#  'data/obj/ff2e20eef38dd4ad.jpg',
#  'data/obj/ff2e673d1d939457.jpg',
#  'data/obj/ff2e70d18d96a7c7.jpg',
#  'data/obj/ff30ff5c12b60cff.jpg',
#  'data/obj/ff37c077e3c0ec95.jpg',
#  'data/obj/ff37ced94c1df307.jpg',
#  'data/obj/ff37e261794bba19.jpg',
#  'data/obj/ff3ae788ca90d85e.jpg',
#  'data/obj/ff3f19594485574f.jpg',
#  'data/obj/ff3f375f65abf21f.jpg',
#  'data/obj/ff3fc006b717b3a6.jpg',
#  'data/obj/ff4079ba5fd25412.jpg',
#  'data/obj/ff4166284b4d3876.jpg',
#  'data/obj/ff447a8435ae88f7.jpg',
#  'data/obj/ff47cdbab70deaf6.jpg',
#  'data/obj/ff4964eea75a1d6f.jpg',
#  'data/obj/ff4aa792c6889daf.jpg',
#  'data/obj/ff4d25aa2b6a3c8c.jpg',
#  'data/obj/ff4ec29b9d213a87.jpg',
#  'data/obj/ff50e568bbcf40fe.jpg',
#  'data/obj/ff5806a20735b2ae.jpg',
#  'data/obj/ff59c7fead73fcf7.jpg',
#  'data/obj/ff5b0f0fda50425d.jpg',
#  'data/obj/ff5e3585dfbb69a5.jpg',
#  'data/obj/ff61a29db6c9e0c5.jpg',
#  'data/obj/ff638ea9e34e7fe7.jpg',
#  'data/obj/ff673c055bfa0f15.jpg',
#  'data/obj/ff687951ef2be403.jpg',
#  'data/obj/ff6af7a5197b67b8.jpg',
#  'data/obj/ff6c16cec1a21f02.jpg',
#  'data/obj/ff6ca7a9d1cb1a54.jpg',
#  'data/obj/ff6d1b2ebebc13fc.jpg',
#  'data/obj/ff6daa26261342f7.jpg',
#  'data/obj/ff778bb1fa806ffc.jpg',
#  'data/obj/ff7c46acdfa32e46.jpg',
#  'data/obj/ff7d9c10ce303feb.jpg',
#  'data/obj/ff7da457b54ca097.jpg',
#  'data/obj/ff80af4f36eb6623.jpg',
#  'data/obj/ff836729ba2bb740.jpg',
#  'data/obj/ff8483695872d807.jpg',
#  'data/obj/ff8cf145ee66a647.jpg',
#  'data/obj/ff8f2bb7ef7386e5.jpg',
#  'data/obj/ff906a0221e05c7d.jpg',
#  'data/obj/ff967935b292e462.jpg',
#  'data/obj/ff986f449b92027b.jpg',
#  'data/obj/ff9b9a2dc998c890.jpg',
#  'data/obj/ff9e0059c8f3e7ba.jpg',
#  'data/obj/ffa9be2973c5b3f4.jpg',
#  'data/obj/ffac29abecf3c522.jpg',
#  'data/obj/ffac6f2a0837e98f.jpg',
#  'data/obj/ffaea7091a84e734.jpg',
#  'data/obj/ffb0b0a299595f9a.jpg',
#  'data/obj/ffb35a09f6802c25.jpg',
#  'data/obj/ffb970c7dd047d55.jpg',
#  'data/obj/ffba4b94677321df.jpg',
#  'data/obj/ffba60a390909f10.jpg',
#  'data/obj/ffbaa4028cc2878b.jpg',
#  'data/obj/ffbcab4e95e78dbd.jpg',
#  'data/obj/ffbccfb6b2a59639.jpg',
#  'data/obj/ffbea7f316329ec4.jpg',
#  'data/obj/ffbf9d1e2f981271.jpg',
#  'data/obj/ffc158a1132b8e4d.jpg',
#  'data/obj/ffc225384bb1ced5.jpg',
#  'data/obj/ffc8a067782c1f71.jpg',
#  'data/obj/ffcd901351d63b1c.jpg',
#  'data/obj/ffcfc94f28c2b91f.jpg',
#  'data/obj/ffd22a636260ca9c.jpg',
#  'data/obj/ffd432f4cf11f55c.jpg',
#  'data/obj/ffd4f37dcce4c11d.jpg',
#  'data/obj/ffd5e166476f993f.jpg',
#  'data/obj/ffd6c3e8c0839eff.jpg',
#  'data/obj/ffd7c7eac4063e09.jpg',
#  'data/obj/ffdb6ca834023bb1.jpg',
#  'data/obj/ffde815b1b5afde5.jpg',
#  'data/obj/ffe071ce38ef7c0b.jpg',
#  'data/obj/ffe14ce6a419fff2.jpg',
#  'data/obj/ffe2715774012420.jpg',
#  'data/obj/ffe3f4c718e9ad0d.jpg',
#  'data/obj/ffe41f2f9a3a9c8f.jpg',
#  'data/obj/ffe4e8bae6352025.jpg',
#  'data/obj/ffe59a4afa6ff7bb.jpg',
#  'data/obj/fff11185281facb4.jpg',
#  'data/obj/fff485d69ab3fc0e.jpg',
#  'data/obj/fff825d10cc676a8.jpg',
#  'data/obj/fff9c0fb92c742d8.jpg',
#  'data/obj/fffc911d5fd290f5.jpg',
#  'data/obj/ffffd60a12c5dc33.jpg']
