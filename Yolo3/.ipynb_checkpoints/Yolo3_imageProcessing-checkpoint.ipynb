# %% [markdown]
# <h1>Image pre-processing for object-detection model</h1>
# <p style="color:blue;font-size:18px;">Step 1: Read imges</p>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import random

# %%
# Defining global variable path that contains train / train_resized folders
image_folder = "/Users/peisch/code/WebScraper/ComputerVision_WebScraper/Images"

# Function to load folder into arrays and then it returns that same array
def loadImages(path):
    image_files = sorted([os.path.join(path, 'train', file)
         for file in os.listdir(path + "/train") if file.endswith('.jpg')])
    return image_files

# %%
# Check number of images in training set
len(loadImages(image_folder))
# Out:
# 1121

# %% [markdown]
# <p style="color:blue;font-size:18px;">Step 2: Resize images</p>

# %%
# Display one image
def display_one(a, title1 = "Original"):
    plt.imshow(a), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.show()

# Display two images
def display(a, b, title1 = "Original", title2 = "Edited"):
    plt.subplot(121), plt.imshow(a), plt.title(title1)
    plt.xticks([]), plt.yticks([])
    plt.subplot(122), plt.imshow(b), plt.title(title2)
    plt.xticks([]), plt.yticks([])
    plt.show()

# %%
# Resize images into dimension determined and save resized images in new folder
# Generate a csv file including image information ie. origin weight/height, new width/height
# BE CAREFUL: we use "image_folder" global variable defined at the beginnning of the notebook

def resizing(data):
    
    # in the path given, create a folder for upcoming resized images if not existing
    os.chdir(image_folder)
    try:
        os.makedirs('train_resized')
    except FileExistsError:
        print("Directory 'train_resized' already exists. Resizing processing ... ")
        
    # Loop: for each image in the folder, store the 1/image, 2/origin size, 3/filename as imageId
    
    # create a dataframe to store information with determined typing for each column
    dtypes = np.dtype([
          ('imageId', str),
          ('origin_width', int),
          ('origin_height', int),
          ('new_width', int),
          ('new_height', int),
          ])
    empty_data = np.empty(0, dtype=dtypes)
    df = pd.DataFrame(empty_data)
    img_list = []
    
    # set working directory (folder) to store processed images
    working_dir = image_folder + "/train_resized/"
    os.chdir(working_dir)
        
    # setting dimemsion of the resized image and update count for processed images
    count:int = 0
    height:int = 256
    width:int = 256
    dim = (width, height) # dimension is a tuple
    res_img = []
    
    # for each absolute path in the list 'data':
    # 1/read image; 2/get its origin image and imageID; 3/update image list;
    # 4/store info in dataframe; 5/store resized image in created "train_resized" folder
    
    for imgStr in data:
        img = [cv2.imread(imgStr, cv2.IMREAD_UNCHANGED)]
        origin_size = img[0].shape # shape of each image is a tuple of (height, weight, channel)
        origin_width = origin_size[1]
        origin_height = origin_size[0]
        imageId = imgStr.rstrip('.jpg').lstrip(image_folder + "/train/")
        img_list[len(img_list):] = [imageId] # equiv to "append" to a list
        #print(f"Original size : {img[0].shape} ; Image ID: {imageId}")
        
        # store info as a new row in the dataframe created above
        col_names = ['imageId', 'origin_width', 'origin_height', 'new_width', 'new_height']
        new_row = pd.DataFrame([[str(imageId), origin_width, origin_height, width, height]], columns = col_names)
        df = df.append(new_row)
        
        # resize image and store as .jpg in created folder
        res = cv2.resize(img[0], dim, interpolation=cv2.INTER_LINEAR)
        res_img.append(res)
        count = count + 1
        filename:str = imageId + ".jpg"
        cv2.imwrite(filename, res)
            
    # Checking the size after processing
    print("Resized image :", res_img[-1].shape)
    
    # Visualizing one of the images in the array
    example_image = res_img[-1]
    display_one(example_image)
    
    # Delete duplicates of the df
    # Save dataframe into a CSV file (write or override .csv file)
    df = df.drop_duplicates()
    df.to_csv('imageTable.csv', index = False)
            
    print(f"Resizing finished. \n [ {count} ] image(s) resized and saved in directory: {working_dir} ")  
    return img_list

# %% [markdown]
# <p style="color:blue;font-size:18px;">Step 3: Recalculate image annotations</p>

# %%
def get_label(images):
    # set working dir to the resized folder 
    working_dir = image_folder + '/train_resized'
    os.chdir(working_dir)
    # load csv file containing image information
    df_img = pd.read_csv('imageTable.csv')
    df_img = df_img.set_index('imageId')
    
    dtypes = np.dtype([
          ('class', str),
          ('origin_xmin', int),
          ('origin_ymin', int),
          ('origin_xmax', int),
          ('origin_ymax', int),
          ('imageId', str)
          ])
    #empty_data = np.empty(0, dtype=dtypes)
    #df = pd.DataFrame(empty_data)
    
    image_buffer:str = ""
    
    for img in images:
        os.chdir(image_folder + '/train/Label')
        image_buffer = img
        filename = img + '.txt'
        # open origin .txt file and get information
        f = open(filename,"r")
        content = f.read()
        # parse content and store in info list
        annotations = content.lstrip().rstrip().split('\n')
        annot_str:str = ""
            
        # each_annot is a string with shape: 'Dress', '483.84', '228.734651', '691.2', '683.0'
        for each_annot in annotations:
            # load info about the origin image stored in csv file
            line = df_img.loc[img]
            o_w = line['origin_width']
            o_h = line['origin_height']
            n_w = line['new_width']
            n_h = line['new_height']
            each_annot = each_annot.replace(",\n", ", ")
            # replace "Dress" by its class number (zero)
            each_annot = each_annot.replace("Dress", "0")
            # now access to information contained by dress and redo the annotation for Yolo3 model
            # annotation for Yolo3: x(centre), y(center), width, height (with all in range [0, 1])
            dress:list = each_annot.split(" ") #list
            xmin = dress[1]
            ymin = dress[2]
            xmax = dress[3]
            ymax = dress[4]
            x = (float(xmin) + float(xmax))/2/o_w
            y = (float(ymin) + float(ymax))/2/o_h
            box_w = (float(xmax)-float(xmin))/o_w
            box_h = (float(ymax)-float(ymin))/o_h
            # the string has the right form for yolo annotation
            each_box:str = f"0 {x} {y} {box_w} {box_h}"
            annot_str:str = each_box + "\n" + annot_str
        annot_str = annot_str.rstrip()
        f.close
        
        # create a folder to store .txt files named 'new_labels'
        os.chdir(image_folder)
        try: os.mkdir('new_labels') 
        except: FileExistsError
        os.chdir(image_folder + '/new_labels')    
        new_file = open(filename,"w")
        n = new_file.write(annot_str)
        new_file.close()
        
    print(f"New annotation .txt files had been saved in directory: {image_folder}/new_labels ")

# %% [markdown]
# <p style="color:blue;font-size:18px;">Step 4: Create train and test path files</p>

# %%
# this function is to produce train.txt and test.txt files used in Yolo3 training
def create_txt_file(img_list):
    # full path list
    store_list = []
    for i in range(len(img_list)): 
        img_path = f"data/obj/{img_list[i]}.jpg"
        store_list.append(img_path)
    
    # randomise train set and test set
    img_nb = len(store_list)
    # parameter of the dataset separation ratio
    train_r = 0.8
    test_r = 0.2
    train_nb = round(img_nb * train_r)
    test_nb = img_nb - train_nb
    
    train_index = random.sample(range(img_nb), k = train_nb)
    # train path list
    train_list = []
    for i in train_index : 
        path = store_list[i]
        train_list.append(path)
    # test path list
    test_list = list(set(store_list) - set(train_list))
    print(f"Set separation done. Train set size: {len(train_list)}. Test set size: {len(test_list)}.")
    
    # save those lists into .txt files
    # create a folder to store .txt files named 'train_test_file'
    os.chdir(image_folder)
    try: os.mkdir('train_test_path') 
    except: FileExistsError
    os.chdir(image_folder + '/train_test_path')
    
    # create and save train.txt
    train_str = '\n'.join(train_list)
    file1 = open("train.txt", "w")
    n = file1.write(train_str)
    file1.close()
    print(f"train.txt file had been saved in directory: {image_folder}/train_test_path")
    
     # create and save test.txt
    test_str = '\n'.join(test_list)
    file2 = open("test.txt", "w")
    n = file2.write(test_str)
    file2.close()
    print(f"test.txt file had been saved in directory: {image_folder}/train_test_path")
    
    return store_list

# %% [markdown]
# <p style="color:blue;font-size:18px;">Execute sequential functions</p>

# %%
# Load data with given image folder path
dataset = loadImages(image_folder)

# Call the resizing function over data and save imageTable.csv
images = resizing(dataset)

# Process all label .txt files and save new .txt files in new_labels folder
get_label(images)

# Create path file for Yolo3 training
create_txt_file(images)
# Out:
# Directory 'train_resized' already exists. Resizing processing ...
# Resized image : (256, 256, 3)
# Resizing finished.
#  [ 1121 ] image(s) resized and saved in directory: /Users/peisch/code/WebScraper/ComputerVision_WebScraper/Images/train_resized/
# New annotation .txt files had been saved in directory: /Users/peisch/code/WebScraper/ComputerVision_WebScraper/Images/new_labels
# Set separation done. Train set size: 897. Test set size: 224.
# train.txt file had been saved in directory: /Users/peisch/code/WebScraper/ComputerVision_WebScraper/Images/train_test_path
# test.txt file had been saved in directory: /Users/peisch/code/WebScraper/ComputerVision_WebScraper/Images/train_test_path
# ['data/obj/12f4e7daaee2a121.jpg',
#  'data/obj/12f890bbf89e1bff.jpg',
#  'data/obj/12f9f5c161df06d6.jpg',
#  'data/obj/12fa50d1915f1775.jpg',
#  'data/obj/12fa58097eedc971.jpg',
#  'data/obj/12fbdf28a097bf56.jpg',
#  'data/obj/12fe1d7790012952.jpg',
#  'data/obj/12ff0959e967cc33.jpg',
#  'data/obj/12ffe82b62b1ae9f.jpg',
#  'data/obj/130083d4f6feaeba.jpg',
#  'data/obj/13033372450b0876.jpg',
#  'data/obj/130377d3785a302e.jpg',
#  'data/obj/130661c3dff01e13.jpg',
#  'data/obj/13066918ba3cc3f4.jpg',
#  'data/obj/13091c2d9856e42b.jpg',
#  'data/obj/13092c4db319eb0d.jpg',
#  'data/obj/130966dddd8cd16b.jpg',
#  'data/obj/1309f43e98642d88.jpg',
#  'data/obj/130b8744e170f0f3.jpg',
#  'data/obj/1312125395bf5e7d.jpg',
#  'data/obj/13123148a4210a5a.jpg',
#  'data/obj/1313cb27b9174bd3.jpg',
#  'data/obj/1316d2d5710380ff.jpg',
#  'data/obj/13179a5e4a335ff7.jpg',
#  'data/obj/131913a137ef6a9d.jpg',
#  'data/obj/131caa87976dcbd9.jpg',
#  'data/obj/131de9f0fc57a2f3.jpg',
#  'data/obj/131fed16482518bc.jpg',
#  'data/obj/132224964da300d5.jpg',
#  'data/obj/1322f95c1535a01b.jpg',
#  'data/obj/1323a5db94e9d61a.jpg',
#  'data/obj/1324898df3725372.jpg',
#  'data/obj/13258161b39f5706.jpg',
#  'data/obj/1325a9e316800a28.jpg',
#  'data/obj/13268f855a827bc1.jpg',
#  'data/obj/1331b559b97ae3d7.jpg',
#  'data/obj/1332114cafacc4c0.jpg',
#  'data/obj/133221b3d8f01cd8.jpg',
#  'data/obj/13348a5f94d5ee43.jpg',
#  'data/obj/13364ac9ec934af2.jpg',
#  'data/obj/1336e2d6d3bbf29f.jpg',
#  'data/obj/1338c8d2133f1e36.jpg',
#  'data/obj/133aef016993b9da.jpg',
#  'data/obj/133b260baad89be6.jpg',
#  'data/obj/133c3d3944e89ebe.jpg',
#  'data/obj/133e06b6395a1964.jpg',
#  'data/obj/1340ece66092f4f4.jpg',
#  'data/obj/1341e06d86c7af6f.jpg',
#  'data/obj/13449e992842180a.jpg',
#  'data/obj/13453a670a4b75b0.jpg',
#  'data/obj/134550d08533e20a.jpg',
#  'data/obj/1347bd8684e22dd0.jpg',
#  'data/obj/13497f8d9b7b4045.jpg',
#  'data/obj/134bc7c60b1466bc.jpg',
#  'data/obj/134d6629c48d2702.jpg',
#  'data/obj/134fc02271eeb5b0.jpg',
#  'data/obj/1350d01609851db0.jpg',
#  'data/obj/1352d0179f7cd00e.jpg',
#  'data/obj/13544944293bcf60.jpg',
#  'data/obj/135b55471fa52e63.jpg',
#  'data/obj/135ea166d3b8dd5f.jpg',
#  'data/obj/135effe1237a254e.jpg',
#  'data/obj/135fec7df8e1bc7f.jpg',
#  'data/obj/136182e2b80203e2.jpg',
#  'data/obj/1366cbc2c6b618be.jpg',
#  'data/obj/136c1755c22af7a8.jpg',
#  'data/obj/136d25da3adcee96.jpg',
#  'data/obj/136dd95fa682bbe8.jpg',
#  'data/obj/136fb49bca5a3e79.jpg',
#  'data/obj/1371739e8a888bec.jpg',
#  'data/obj/137405b303fc2264.jpg',
#  'data/obj/137abfad54e45550.jpg',
#  'data/obj/137d6ace04acb8e5.jpg',
#  'data/obj/137d8c07f889818b.jpg',
#  'data/obj/1380f3989f37e637.jpg',
#  'data/obj/13840b4dce8f5904.jpg',
#  'data/obj/138fa176e7d1c2d9.jpg',
#  'data/obj/13914c0131d96fb5.jpg',
#  'data/obj/13984baf16aaaf6c.jpg',
#  'data/obj/139d0e5c3656b9ee.jpg',
#  'data/obj/139da19e7c8d1ea2.jpg',
#  'data/obj/13a1fae8afbb9b62.jpg',
#  'data/obj/13a25d483f48215a.jpg',
#  'data/obj/13a339da80405a05.jpg',
#  'data/obj/13a3da0282e1fe1a.jpg',
#  'data/obj/13a41f6f78a2d92e.jpg',
#  'data/obj/13a43966edc35033.jpg',
#  'data/obj/13a445e1d2bb6dd4.jpg',
#  'data/obj/13a89398abdd7516.jpg',
#  'data/obj/13adef5937b8d022.jpg',
#  'data/obj/13af313fd70760ea.jpg',
#  'data/obj/13af3feddb073055.jpg',
#  'data/obj/13b993910d82d700.jpg',
#  'data/obj/13b9a6cafa1b3ac8.jpg',
#  'data/obj/13b9d3c0063c86b0.jpg',
#  'data/obj/13b9d761cf8e7ef6.jpg',
#  'data/obj/13baa53a608d7296.jpg',
#  'data/obj/13bbe26861f36a47.jpg',
#  'data/obj/13bcad5ea57e7963.jpg',
#  'data/obj/13bd0fce39365b69.jpg',
#  'data/obj/13bd782a5617c8f0.jpg',
#  'data/obj/13c0c89c5ecdfd1a.jpg',
#  'data/obj/13c1b0f326287ca6.jpg',
#  'data/obj/13c3c2fea4d6e83e.jpg',
#  'data/obj/13c6c7a3350fb575.jpg',
#  'data/obj/13c7384f5921a584.jpg',
#  'data/obj/13c9746900813815.jpg',
#  'data/obj/13ca1e7c8a7bde1d.jpg',
#  'data/obj/13ce21b86c8c98a2.jpg',
#  'data/obj/13d03d06065216d1.jpg',
#  'data/obj/13d058414716535b.jpg',
#  'data/obj/13d38ff46fbb2a68.jpg',
#  'data/obj/13d479fb9207965a.jpg',
#  'data/obj/13d5b1e6ab2f75c4.jpg',
#  'data/obj/13e1eae7400fc5ae.jpg',
#  'data/obj/13e3e144bbea13b2.jpg',
#  'data/obj/13e57405d15e1c26.jpg',
#  'data/obj/13e624f3dd75d2ef.jpg',
#  'data/obj/13e72ec570f84ad2.jpg',
#  'data/obj/13e8ed22d52dd935.jpg',
#  'data/obj/13e90ce693871953.jpg',
#  'data/obj/13ecc48290e26721.jpg',
#  'data/obj/13ecfcc0c4c49f16.jpg',
#  'data/obj/13f01494dc334277.jpg',
#  'data/obj/13f0ec572d23e48e.jpg',
#  'data/obj/13f18ff6e2e0475c.jpg',
#  'data/obj/13f33906f451edf4.jpg',
#  'data/obj/13f46449956e6bec.jpg',
#  'data/obj/13f52fd0ae4f80eb.jpg',
#  'data/obj/13f67dee14b62bc2.jpg',
#  'data/obj/13f7c90033599d83.jpg',
#  'data/obj/13f910cbb6a94ad5.jpg',
#  'data/obj/13f94e4a90722f26.jpg',
#  'data/obj/14003faf14952b24.jpg',
#  'data/obj/14011ae05c44445f.jpg',
#  'data/obj/14013ac628a6f7c3.jpg',
#  'data/obj/140c2f737f7f45c5.jpg',
#  'data/obj/140c681a71d0a1a0.jpg',
#  'data/obj/140ca3fef8ed1da6.jpg',
#  'data/obj/140da8e4452613c1.jpg',
#  'data/obj/140e14d61ef54d00.jpg',
#  'data/obj/140f984cff94e8e6.jpg',
#  'data/obj/141064919a2e5046.jpg',
#  'data/obj/141098dbc8e54cdb.jpg',
#  'data/obj/1412e815cde13ab0.jpg',
#  'data/obj/1415cf1d9fd75db3.jpg',
#  'data/obj/1415d825abf8aebc.jpg',
#  'data/obj/141793f844f725a4.jpg',
#  'data/obj/141955b8e994b251.jpg',
#  'data/obj/14199d1d5f5644ff.jpg',
#  'data/obj/141a332e93f391c8.jpg',
#  'data/obj/141aacd14b120a63.jpg',
#  'data/obj/141bfe808c0bbaf9.jpg',
#  'data/obj/141c0ba89ff82b23.jpg',
#  'data/obj/141ec8005e1fb427.jpg',
#  'data/obj/14215c0e95f9517c.jpg',
#  'data/obj/1424f6727462c8f7.jpg',
#  'data/obj/1426316c20179c43.jpg',
#  'data/obj/1428fa9f6029cd2d.jpg',
#  'data/obj/142a070e90047cb7.jpg',
#  'data/obj/142ebd0df6a156d0.jpg',
#  'data/obj/1431aae4b43de906.jpg',
#  'data/obj/1431dd222eb8a445.jpg',
#  'data/obj/143233ebc820ee5c.jpg',
#  'data/obj/143b139e42c434ad.jpg',
#  'data/obj/143be910d0730e63.jpg',
#  'data/obj/143fe8fe12398868.jpg',
#  'data/obj/1443be5df67af2b6.jpg',
#  'data/obj/1443e18759cec1ce.jpg',
#  'data/obj/14460004b81a6003.jpg',
#  'data/obj/14470006b2d3c828.jpg',
#  'data/obj/1449f006d344f544.jpg',
#  'data/obj/144a0ab454ccf317.jpg',
#  'data/obj/144cf5a2c41174ed.jpg',
#  'data/obj/144f9ed0e4e9a972.jpg',
#  'data/obj/1450fb70c3f3e56b.jpg',
#  'data/obj/14539be4683ab5e0.jpg',
#  'data/obj/145409aacdd2c07f.jpg',
#  'data/obj/145459410f7ce5d4.jpg',
#  'data/obj/1457ca3b70b95bbb.jpg',
#  'data/obj/145b98fbe7767ab6.jpg',
#  'data/obj/145f2926e1d807ad.jpg',
#  'data/obj/14613362a9b32107.jpg',
#  'data/obj/14650dd9533310b0.jpg',
#  'data/obj/14655d1bf8961962.jpg',
#  'data/obj/1465b48318174457.jpg',
#  'data/obj/1466dc470dd42698.jpg',
#  'data/obj/146e9ec629c58f6b.jpg',
#  'data/obj/146ea00d78d7737c.jpg',
#  'data/obj/146f99f2b1adcef4.jpg',
#  'data/obj/14703406bf41af46.jpg',
#  'data/obj/147209deb5e9c385.jpg',
#  'data/obj/14769b2810a2a2e2.jpg',
#  'data/obj/14777da981934e08.jpg',
#  'data/obj/147a49fd11a5af37.jpg',
#  'data/obj/147f3081b4429987.jpg',
#  'data/obj/14837914840d4d0e.jpg',
#  'data/obj/1486e33977c45d11.jpg',
#  'data/obj/1487a22ab1e9e6e4.jpg',
#  'data/obj/148e1d454a568985.jpg',
#  'data/obj/148e5ea09b771201.jpg',
#  'data/obj/148fbd8abd8b7269.jpg',
#  'data/obj/14907126d3770631.jpg',
#  'data/obj/149d96c6609c9229.jpg',
#  'data/obj/149db8e141c04644.jpg',
#  'data/obj/149dcba9f3ddf959.jpg',
#  'data/obj/14a1d4c40eb3064b.jpg',
#  'data/obj/14a267a8fd335446.jpg',
#  'data/obj/14a7abd9e2a94cb1.jpg',
#  'data/obj/14abb5e06e15c712.jpg',
#  'data/obj/14b0c34aca1cb943.jpg',
#  'data/obj/14b2c7a6489227ae.jpg',
#  'data/obj/14b4011db64da2ba.jpg',
#  'data/obj/14b552110df9ae6a.jpg',
#  'data/obj/14b99150871bc938.jpg',
#  'data/obj/14be98dcf09ac1f6.jpg',
#  'data/obj/14bebda3ea229d26.jpg',
#  'data/obj/14bfa5f564366e0a.jpg',
#  'data/obj/14c08ee0eb9c9279.jpg',
#  'data/obj/14c601153f6a0583.jpg',
#  'data/obj/14c7a95e21145d9a.jpg',
#  'data/obj/14c8af14215a9ecd.jpg',
#  'data/obj/14cc67194e80ab97.jpg',
#  'data/obj/14cdfedc27a09256.jpg',
#  'data/obj/14ce66000df4dcaa.jpg',
#  'data/obj/14d238c17cb69c8f.jpg',
#  'data/obj/14d380ad05f57a64.jpg',
#  'data/obj/14d4ad35fd7ba62d.jpg',
#  'data/obj/14d5bf6ab141f520.jpg',
#  'data/obj/14d7ca6a62cddcba.jpg',
#  'data/obj/14de2521ef4d5d86.jpg',
#  'data/obj/14e23e97193e5e0a.jpg',
#  'data/obj/14e2d5d047830048.jpg',
#  'data/obj/14e334a587813267.jpg',
#  'data/obj/14e79cf69ae34185.jpg',
#  'data/obj/14eb9cc288f6bc91.jpg',
#  'data/obj/14eda5c48d0f5efc.jpg',
#  'data/obj/14f068e0bf9db7d9.jpg',
#  'data/obj/14f5bd29006aa7d4.jpg',
#  'data/obj/14faa0f18ed5e4e7.jpg',
#  'data/obj/15044c2a4501bfbb.jpg',
#  'data/obj/1504c87577bd70ef.jpg',
#  'data/obj/150b06996c7ad4c7.jpg',
#  'data/obj/150c06b60d71913c.jpg',
#  'data/obj/15101a5afcc22a94.jpg',
#  'data/obj/1511432f3e1c2a05.jpg',
#  'data/obj/1512fcd7c2e12955.jpg',
#  'data/obj/1513027ec588c83b.jpg',
#  'data/obj/1514d0b4883ecbee.jpg',
#  'data/obj/151562ef17e5ba53.jpg',
#  'data/obj/151705c5813a67e9.jpg',
#  'data/obj/151ad9e15a497dd0.jpg',
#  'data/obj/151c874db6f05707.jpg',
#  'data/obj/151f447f2b78bcab.jpg',
#  'data/obj/1520bd0da46b4218.jpg',
#  'data/obj/15227a6091567504.jpg',
#  'data/obj/1522831535a34010.jpg',
#  'data/obj/1525ef93c331fdab.jpg',
#  'data/obj/15286a81596a2e73.jpg',
#  'data/obj/15289cfba76454fb.jpg',
#  'data/obj/1528ebbae7630a2d.jpg',
#  'data/obj/152a5c4f0bb3f76d.jpg',
#  'data/obj/152ae4a09386ba93.jpg',
#  'data/obj/152c45fe8f637ed4.jpg',
#  'data/obj/152df8218739e7bb.jpg',
#  'data/obj/1532e63c80278ca7.jpg',
#  'data/obj/1537ae8305ddae1e.jpg',
#  'data/obj/15435ba7dcd36a5e.jpg',
#  'data/obj/15446376d8a39e40.jpg',
#  'data/obj/154786c4ce8e263e.jpg',
#  'data/obj/1547e2b29dd8179c.jpg',
#  'data/obj/15487c6515ed970d.jpg',
#  'data/obj/154a341cd07f1ea0.jpg',
#  'data/obj/154ab6aa7ec7ce3d.jpg',
#  'data/obj/154dfd5b50335610.jpg',
#  'data/obj/154fbc275965086f.jpg',
#  'data/obj/154fc0d89df22d68.jpg',
#  'data/obj/1550cb403f807f8d.jpg',
#  'data/obj/1552c9ea9697826c.jpg',
#  'data/obj/1553e74952626b66.jpg',
#  'data/obj/15546363e7dc80c0.jpg',
#  'data/obj/1554fbc11beaf456.jpg',
#  'data/obj/1558522f1dbc2b4b.jpg',
#  'data/obj/155cdee8ca24382b.jpg',
#  'data/obj/155ce5e629ca4077.jpg',
#  'data/obj/155d61c942a7499d.jpg',
#  'data/obj/1560493623bc7948.jpg',
#  'data/obj/1566d4bb35dea01d.jpg',
#  'data/obj/1568f6de527b16fe.jpg',
#  'data/obj/156af43d923ffe75.jpg',
#  'data/obj/156dbb581cbb4056.jpg',
#  'data/obj/156f92a83bd86a33.jpg',
#  'data/obj/15722f64f37c60bf.jpg',
#  'data/obj/15742c720586b32f.jpg',
#  'data/obj/157457f3d453a308.jpg',
#  'data/obj/157afbcef5805fb3.jpg',
#  'data/obj/157b202db669fa8f.jpg',
#  'data/obj/157e375635ae8a84.jpg',
#  'data/obj/1580697689696314.jpg',
#  'data/obj/1580ec8376099f50.jpg',
#  'data/obj/15836c3817a929e7.jpg',
#  'data/obj/1584b72c1d16a74e.jpg',
#  'data/obj/15877b6ce0786928.jpg',
#  'data/obj/158a154c395749d6.jpg',
#  'data/obj/158a41b081d1507e.jpg',
#  'data/obj/158b45fce5354b42.jpg',
#  'data/obj/158e641a901111d7.jpg',
#  'data/obj/15928569e5743fa5.jpg',
#  'data/obj/1598b3a130576832.jpg',
#  'data/obj/1599db99b8a49984.jpg',
#  'data/obj/159d5d11c3696bb3.jpg',
#  'data/obj/159e590070af4f41.jpg',
#  'data/obj/159f762c8baf9289.jpg',
#  'data/obj/15a31c00e44b42b1.jpg',
#  'data/obj/15a50e32bdf6ecde.jpg',
#  'data/obj/15a696cbfcddfe69.jpg',
#  'data/obj/15a6bf8dd1fd6e15.jpg',
#  'data/obj/15ab8b17c644a15f.jpg',
#  'data/obj/15ad36f52e3ccb06.jpg',
#  'data/obj/15ad74a0523ec4b5.jpg',
#  'data/obj/15aeeae8376158a9.jpg',
#  'data/obj/15b0579ffb5fd3c6.jpg',
#  'data/obj/15b1683d26f2a0d3.jpg',
#  'data/obj/15b2fedfefb16572.jpg',
#  'data/obj/15bb7f2ff130d4cc.jpg',
#  'data/obj/15bbd42e15317124.jpg',
#  'data/obj/15bbfe4ded9e0ba2.jpg',
#  'data/obj/15bd93665dd2d01f.jpg',
#  'data/obj/15bf29dc4a3aacd8.jpg',
#  'data/obj/15c05ed4378564bf.jpg',
#  'data/obj/15c33f8a4a613da6.jpg',
#  'data/obj/15c461591b0dbd25.jpg',
#  'data/obj/15c4bc37c5e4cf67.jpg',
#  'data/obj/15c5573db3a77e7d.jpg',
#  'data/obj/15c7f467e6421982.jpg',
#  'data/obj/15c82ebd7b64eef0.jpg',
#  'data/obj/15c8cdc7c9721eb6.jpg',
#  'data/obj/15cdf051240524d2.jpg',
#  'data/obj/15d272206feaa934.jpg',
#  'data/obj/15d40b9b7629b793.jpg',
#  'data/obj/15d464f6c4bb5f02.jpg',
#  'data/obj/15d472b07a66c7bf.jpg',
#  'data/obj/15d48573eacc7386.jpg',
#  'data/obj/15d5c2c5fa9a1048.jpg',
#  'data/obj/15d5fb33cacd38ba.jpg',
#  'data/obj/15d7c14966fc2aae.jpg',
#  'data/obj/15d83e3a0ed1c65d.jpg',
#  'data/obj/15d87f259724ea9b.jpg',
#  'data/obj/15d8e2add5e60277.jpg',
#  'data/obj/15d928ec7261e15b.jpg',
#  'data/obj/15de3d3c167da2e8.jpg',
#  'data/obj/15de650304e658e6.jpg',
#  'data/obj/15defaab8ed6dc28.jpg',
#  'data/obj/15df6435ae39d7df.jpg',
#  'data/obj/15e2514ef11d9698.jpg',
#  'data/obj/15e87efc6891d18c.jpg',
#  'data/obj/15e91f33f22f83c9.jpg',
#  'data/obj/15ec1e230d7a3677.jpg',
#  'data/obj/15ee8b5049d62d98.jpg',
#  'data/obj/15f1853229e5dbd6.jpg',
#  'data/obj/15f245f3c2757b17.jpg',
#  'data/obj/15f500cdb1b42a95.jpg',
#  'data/obj/15f5788c082899c5.jpg',
#  'data/obj/15f978062d0f7e5a.jpg',
#  'data/obj/15fa08bce2e25f5e.jpg',
#  'data/obj/15fd43fc0ee27588.jpg',
#  'data/obj/15fd5b033a75c521.jpg',
#  'data/obj/15febd7c9dbbd882.jpg',
#  'data/obj/15ff11fa634b573d.jpg',
#  'data/obj/16018a975a85204c.jpg',
#  'data/obj/1604ba73b710e872.jpg',
#  'data/obj/1605f296eb384708.jpg',
#  'data/obj/1606ee86b95a0472.jpg',
#  'data/obj/161205364617df4f.jpg',
#  'data/obj/16125072348de0e5.jpg',
#  'data/obj/1613d1c7f03d3b20.jpg',
#  'data/obj/16146c9ad6e8d36a.jpg',
#  'data/obj/1615dcffd02e09d7.jpg',
#  'data/obj/1618701de0b69c75.jpg',
#  'data/obj/1620ab82699eb801.jpg',
#  'data/obj/1624368a239b592b.jpg',
#  'data/obj/16265eb7c911044c.jpg',
#  'data/obj/162abc247722a5b9.jpg',
#  'data/obj/162b7b0400966d10.jpg',
#  'data/obj/162ba5e2e3bf6845.jpg',
#  'data/obj/162ea40f741570a1.jpg',
#  'data/obj/162ebe73f91c912a.jpg',
#  'data/obj/162f8f18e4483888.jpg',
#  'data/obj/162ff898b14789da.jpg',
#  'data/obj/163009345c9ff8d6.jpg',
#  'data/obj/1631721f16a4ddda.jpg',
#  'data/obj/1632365fdcea23e8.jpg',
#  'data/obj/1632c339cff14709.jpg',
#  'data/obj/1634687f52154b71.jpg',
#  'data/obj/1635a79a9afc537c.jpg',
#  'data/obj/16397dfc08a7bd07.jpg',
#  'data/obj/163d23030dc543e6.jpg',
#  'data/obj/163e087da8c0a978.jpg',
#  'data/obj/16416dafb16000ab.jpg',
#  'data/obj/1642ea1f2e2d502c.jpg',
#  'data/obj/16434f5f4764c3ed.jpg',
#  'data/obj/16435f39aeac60a7.jpg',
#  'data/obj/16444d9ffa1a7bdb.jpg',
#  'data/obj/16457d20f725be7f.jpg',
#  'data/obj/1646e98557ff16dc.jpg',
#  'data/obj/16483717a6764805.jpg',
#  'data/obj/164852ceaf4db2d9.jpg',
#  'data/obj/164df4645da21f88.jpg',
#  'data/obj/165343ad37228c59.jpg',
#  'data/obj/165491364c2a4134.jpg',
#  'data/obj/165ae7ff1a0be563.jpg',
#  'data/obj/165b5ea3ebea1d40.jpg',
#  'data/obj/165cacb7df3aa97d.jpg',
#  'data/obj/165dac15c9a12a32.jpg',
#  'data/obj/165dfa07cb07009d.jpg',
#  'data/obj/16631bf2f1321050.jpg',
#  'data/obj/166438db169b64b4.jpg',
#  'data/obj/16687d8349b8467f.jpg',
#  'data/obj/166c2b80c2824ab7.jpg',
#  'data/obj/166feab18ae3cca0.jpg',
#  'data/obj/1670714de9de4ca0.jpg',
#  'data/obj/16731b3b867f0a80.jpg',
#  'data/obj/16732da67b6168d1.jpg',
#  'data/obj/1678af475e6e9ee4.jpg',
#  'data/obj/167db21f5cb2a9a2.jpg',
#  'data/obj/167de21a8e7e9e6e.jpg',
#  'data/obj/167f0132fce5a368.jpg',
#  'data/obj/167f908e7ca9e726.jpg',
#  'data/obj/16809cc024cba80c.jpg',
#  'data/obj/1682e3d8ae5ef803.jpg',
#  'data/obj/16849d82891c9101.jpg',
#  'data/obj/1684feab80b16fdb.jpg',
#  'data/obj/16884119b9f28d2f.jpg',
#  'data/obj/168a172852dbb773.jpg',
#  'data/obj/168bca77efad3c1a.jpg',
#  'data/obj/169168c04ab0fee7.jpg',
#  'data/obj/16949061377f6f67.jpg',
#  'data/obj/1694cd941096c5a7.jpg',
#  'data/obj/16a1c0ba8b003cd8.jpg',
#  'data/obj/16a206bccaf1dbc6.jpg',
#  'data/obj/16a70160b7fab6a7.jpg',
#  'data/obj/16a73067cad560cf.jpg',
#  'data/obj/16a81494a726bd41.jpg',
#  'data/obj/16acd463ea54ced0.jpg',
#  'data/obj/16af635151b18613.jpg',
#  'data/obj/16b011a20d74379c.jpg',
#  'data/obj/16b1a842160cb015.jpg',
#  'data/obj/16b2a62b2874e7c0.jpg',
#  'data/obj/16b441517d0164f6.jpg',
#  'data/obj/16b62f363eeb84da.jpg',
#  'data/obj/16b6484a47e4e4bd.jpg',
#  'data/obj/16bb7acb77a69d38.jpg',
#  'data/obj/16be283f708719d1.jpg',
#  'data/obj/16be6255a7b20b6d.jpg',
#  'data/obj/16bee7cddeb2ad47.jpg',
#  'data/obj/16c2c92f64f1d831.jpg',
#  'data/obj/16c913c3efd1d704.jpg',
#  'data/obj/16c93e225d3eb00d.jpg',
#  'data/obj/16cf0e3ed3d23577.jpg',
#  'data/obj/16d0b0e7ad1b31f3.jpg',
#  'data/obj/16d0b9c3cd3c5587.jpg',
#  'data/obj/16d4aeb0f623dc40.jpg',
#  'data/obj/16d642331d40a688.jpg',
#  'data/obj/16d72de90e683727.jpg',
#  'data/obj/16d930b732b472c8.jpg',
#  'data/obj/16d9d09bbb557a3d.jpg',
#  'data/obj/16da6ab0472777ba.jpg',
#  'data/obj/16dcbe0f213ceef7.jpg',
#  'data/obj/16df69be1d6ad75e.jpg',
#  'data/obj/16dfc52d611e083c.jpg',
#  'data/obj/16e4505acae9de15.jpg',
#  'data/obj/16e5d0191e510394.jpg',
#  'data/obj/16e6c5db2959f5fe.jpg',
#  'data/obj/16e704444637e395.jpg',
#  'data/obj/16ea3f3c1c9a81fc.jpg',
#  'data/obj/16ecc1ccf3cafdaa.jpg',
#  'data/obj/16f197c544aecf73.jpg',
#  'data/obj/16f24b06c13ed08f.jpg',
#  'data/obj/16f2bccc36a29db8.jpg',
#  'data/obj/16f2e07129c17ef8.jpg',
#  'data/obj/16f37ea72b6f3e0e.jpg',
#  'data/obj/16f5073dd3646e77.jpg',
#  'data/obj/16f7aab9a6e0378f.jpg',
#  'data/obj/16fe3b8e479aa248.jpg',
#  'data/obj/16fecb192d2a1247.jpg',
#  'data/obj/16ff3d64f4fbb6c3.jpg',
#  'data/obj/1703dd28fcef34ec.jpg',
#  'data/obj/170584429785bff0.jpg',
#  'data/obj/1707b061a350a405.jpg',
#  'data/obj/170a9844382ad70f.jpg',
#  'data/obj/170c0c9ec062d7a2.jpg',
#  'data/obj/170d66456255ab64.jpg',
#  'data/obj/170eaa32309332d6.jpg',
#  'data/obj/17147636f279b80e.jpg',
#  'data/obj/171712d497cac733.jpg',
#  'data/obj/17181c70789024b0.jpg',
#  'data/obj/17184bc7671f6920.jpg',
#  'data/obj/1719c59d11a33668.jpg',
#  'data/obj/171d0b0a4940ac35.jpg',
#  'data/obj/171e0d02b350867f.jpg',
#  'data/obj/171f36e71870a535.jpg',
#  'data/obj/1721ac5d48fc9166.jpg',
#  'data/obj/172288cd0deb9dfa.jpg',
#  'data/obj/172328a16a54f911.jpg',
#  'data/obj/17242fdd43b892ae.jpg',
#  'data/obj/1724a5a2a59823cd.jpg',
#  'data/obj/17277b0212749484.jpg',
#  'data/obj/1727b83f56fd4f67.jpg',
#  'data/obj/17285ad31a7ec04b.jpg',
#  'data/obj/1729e39dc6b02914.jpg',
#  'data/obj/172ded0ca418562e.jpg',
#  'data/obj/172e1a18005f5027.jpg',
#  'data/obj/1734859d4c3440d6.jpg',
#  'data/obj/1734d1a2c6d92fb1.jpg',
#  'data/obj/1737aea0c6c622f7.jpg',
#  'data/obj/1737aee22b141347.jpg',
#  'data/obj/173a195cdb45c304.jpg',
#  'data/obj/173e63743f9eb5f0.jpg',
#  'data/obj/1742d231eddde643.jpg',
#  'data/obj/174a936a23baa9f6.jpg',
#  'data/obj/174bc9ae9a350195.jpg',
#  'data/obj/174c8e1494292cc6.jpg',
#  'data/obj/174cdd653d68862b.jpg',
#  'data/obj/17545cf37fc0015a.jpg',
#  'data/obj/17573983c29f73f9.jpg',
#  'data/obj/1759d00ed0a5ef39.jpg',
#  'data/obj/1759fac3db2e61fa.jpg',
#  'data/obj/175af35881a7ab79.jpg',
#  'data/obj/175e2f51de4edf84.jpg',
#  'data/obj/1763a43059608118.jpg',
#  'data/obj/1767299979e44c2f.jpg',
#  'data/obj/1768eb699ce69b08.jpg',
#  'data/obj/176b41420cafcc00.jpg',
#  'data/obj/176cbbe0fe21765e.jpg',
#  'data/obj/176eebb1d044c047.jpg',
#  'data/obj/176f5c1af2de2b8a.jpg',
#  'data/obj/177115460b43d8b9.jpg',
#  'data/obj/177278804aebf567.jpg',
#  'data/obj/1772a5e9fe88b847.jpg',
#  'data/obj/17731b3c8e4d5a11.jpg',
#  'data/obj/17742f513cb95552.jpg',
#  'data/obj/1774f242e47f3418.jpg',
#  'data/obj/1776d56e0abc6227.jpg',
#  'data/obj/1777dfdcdf3b4045.jpg',
#  'data/obj/177a25453a406990.jpg',
#  'data/obj/177a8e0cb1c9e7e9.jpg',
#  'data/obj/177bc9d76f7bd1e1.jpg',
#  'data/obj/177e1a1d0f1da531.jpg',
#  'data/obj/177ecdff2e454f76.jpg',
#  'data/obj/177fcca091904b0f.jpg',
#  'data/obj/1781aac45204b005.jpg',
#  'data/obj/17869bf276d63d4f.jpg',
#  'data/obj/17881b50f2bd438e.jpg',
#  'data/obj/178c928de8135431.jpg',
#  'data/obj/17904efb7ff02f7e.jpg',
#  'data/obj/17942d99a1df3cab.jpg',
#  'data/obj/179d3da6b9ede8f1.jpg',
#  'data/obj/179e441dc0088d68.jpg',
#  'data/obj/179e464b69b3291e.jpg',
#  'data/obj/179ef0aa44b44243.jpg',
#  'data/obj/179fdf3a292f623b.jpg',
#  'data/obj/17a23c28ca8a192f.jpg',
#  'data/obj/17a276a5d74ac979.jpg',
#  'data/obj/17a5de7eb7906d65.jpg',
#  'data/obj/17a9365064071267.jpg',
#  'data/obj/17aa38b2736b7568.jpg',
#  'data/obj/17add8e4176207c2.jpg',
#  'data/obj/17aff889406a6603.jpg',
#  'data/obj/17b0b4164f954e92.jpg',
#  'data/obj/17b0d77818bcf6d1.jpg',
#  'data/obj/17b46bbc3aac987b.jpg',
#  'data/obj/17bb332bfc75fa21.jpg',
#  'data/obj/17bb9a6fda507379.jpg',
#  'data/obj/17bcecf9952770a8.jpg',
#  'data/obj/17be7e8ad58a5664.jpg',
#  'data/obj/17c0af7d466a948b.jpg',
#  'data/obj/17c25ce43ecee8c9.jpg',
#  'data/obj/17c51a431cfbc54f.jpg',
#  'data/obj/17c52013281f390e.jpg',
#  'data/obj/17c5f5e5ef822d91.jpg',
#  'data/obj/17c78688af402bb4.jpg',
#  'data/obj/17c8a031c5769bb1.jpg',
#  'data/obj/17caecfb8f53c7ed.jpg',
#  'data/obj/17cbccd8f8c794da.jpg',
#  'data/obj/17d052546bf3bb7f.jpg',
#  'data/obj/17d09047277df33e.jpg',
#  'data/obj/17d0b8792acbce6e.jpg',
#  'data/obj/17d2be1ea6680eee.jpg',
#  'data/obj/17d2c164a5ef6da1.jpg',
#  'data/obj/17d3533631173e00.jpg',
#  'data/obj/17d5a5e10483429f.jpg',
#  'data/obj/17d6b0335f19a488.jpg',
#  'data/obj/17d6bcf793a0bab5.jpg',
#  'data/obj/17da02f488a79602.jpg',
#  'data/obj/17dcd3f3f00942da.jpg',
#  'data/obj/17dfecaa3c3b0237.jpg',
#  'data/obj/17e2041ecc09e28c.jpg',
#  'data/obj/17e64bf805bc26e2.jpg',
#  'data/obj/17ece4e8157ca251.jpg',
#  'data/obj/17ee16bf4cfdbc41.jpg',
#  'data/obj/17f1192b85a92ed4.jpg',
#  'data/obj/17f267761b0a7663.jpg',
#  'data/obj/17f43b2597c9625a.jpg',
#  'data/obj/17f69a4da03a8005.jpg',
#  'data/obj/17f79ab8656956e5.jpg',
#  'data/obj/17f86b464b1005bb.jpg',
#  'data/obj/1804487c5a3186c0.jpg',
#  'data/obj/180698f6ae2c25f7.jpg',
#  'data/obj/18076090503abfb4.jpg',
#  'data/obj/180827356f9ffa0c.jpg',
#  'data/obj/1808d6d7e1dd824e.jpg',
#  'data/obj/180dd4942100afbf.jpg',
#  'data/obj/1810b3f2aec93cf2.jpg',
#  'data/obj/18113b17415451ef.jpg',
#  'data/obj/1815808e6d7e0dce.jpg',
#  'data/obj/18158fbd87e04912.jpg',
#  'data/obj/181a76e864e4ddd0.jpg',
#  'data/obj/181cf9f54509d1d2.jpg',
#  'data/obj/181d230f52ea2952.jpg',
#  'data/obj/181d6651922a6ef4.jpg',
#  'data/obj/181d8e1a36456e27.jpg',
#  'data/obj/182215e460352a16.jpg',
#  'data/obj/18277531fef3b2f1.jpg',
#  'data/obj/1827ec3dc79255da.jpg',
#  'data/obj/182923a3f5086b55.jpg',
#  'data/obj/182ab96255b6b9ea.jpg',
#  'data/obj/182b756244d2d59a.jpg',
#  'data/obj/182bbd651f0af908.jpg',
#  'data/obj/182bc5796b0f6236.jpg',
#  'data/obj/1830b39dbff3b54c.jpg',
#  'data/obj/18319e36beb260c5.jpg',
#  'data/obj/1832eae367889492.jpg',
#  'data/obj/183389ee27ec113b.jpg',
#  'data/obj/183442723ed4b4bd.jpg',
#  'data/obj/183c7aaf5b896bf3.jpg',
#  'data/obj/1840d23c9a7a5b57.jpg',
#  'data/obj/184438c3f89ef5ed.jpg',
#  'data/obj/1844b762efaf3af2.jpg',
#  'data/obj/184720ebd89202b0.jpg',
#  'data/obj/1847ac93e932357a.jpg',
#  'data/obj/184cc737f9c1487e.jpg',
#  'data/obj/18523c9da8c16c9c.jpg',
#  'data/obj/18538c340d076e19.jpg',
#  'data/obj/1855bfa099f47886.jpg',
#  'data/obj/1856c37156cf1870.jpg',
#  'data/obj/18581bfbc4665798.jpg',
#  'data/obj/18593e6f719fa258.jpg',
#  'data/obj/185a44d8681cbcf9.jpg',
#  'data/obj/18601d067a501f8f.jpg',
#  'data/obj/1860fb1a5392eebb.jpg',
#  'data/obj/18622b325bcf6b86.jpg',
#  'data/obj/1868055c170ab9a7.jpg',
#  'data/obj/18694e1740fa2aad.jpg',
#  'data/obj/186aa56d177dcd84.jpg',
#  'data/obj/186aaa41db0d31f9.jpg',
#  'data/obj/186bf2096c0adc6e.jpg',
#  'data/obj/186de5036baaa837.jpg',
#  'data/obj/186eb98f0ddbd05f.jpg',
#  'data/obj/187106989ce46097.jpg',
#  'data/obj/18744ea9b9183726.jpg',
#  'data/obj/1875170453aa74e6.jpg',
#  'data/obj/18754fe08fa58b98.jpg',
#  'data/obj/187594de5518de33.jpg',
#  'data/obj/187aa7ea3e337cf6.jpg',
#  'data/obj/187ad270e4d07c96.jpg',
#  'data/obj/187aeffaebe60e1c.jpg',
#  'data/obj/187fe395045fa8dc.jpg',
#  'data/obj/1881531153a786d7.jpg',
#  'data/obj/188402c46b8fd978.jpg',
#  'data/obj/18853a213c936e52.jpg',
#  'data/obj/188731562b9d927d.jpg',
#  'data/obj/18876952a505f205.jpg',
#  'data/obj/188791e54c051eaf.jpg',
#  'data/obj/1888f91a665fcd33.jpg',
#  'data/obj/188a890a1ddc7ff6.jpg',
#  'data/obj/18928d0386034818.jpg',
#  'data/obj/1892bd06c84e0561.jpg',
#  'data/obj/1894e100d48cdcb9.jpg',
#  'data/obj/1896dcbdfd31ee32.jpg',
#  'data/obj/18984282b2c87262.jpg',
#  'data/obj/18990c85505ea064.jpg',
#  'data/obj/189c221a69167d70.jpg',
#  'data/obj/18a6552db078b30e.jpg',
#  'data/obj/18ab3ad2cde119a7.jpg',
#  'data/obj/18add6f2a3735431.jpg',
#  'data/obj/18ae457b1adb8466.jpg',
#  'data/obj/18af13775b04865a.jpg',
#  'data/obj/18b09443dce178ab.jpg',
#  'data/obj/18b0d8bf58a8778a.jpg',
#  'data/obj/18b92d25a760c773.jpg',
#  'data/obj/18ba2f1234329424.jpg',
#  'data/obj/18ba78545ff4b244.jpg',
#  'data/obj/18bdaee56f67baa4.jpg',
#  'data/obj/18c016caf13ff780.jpg',
#  'data/obj/18c249a9b1ee1db3.jpg',
#  'data/obj/18c2a1dc33873f94.jpg',
#  'data/obj/18c2c65170505861.jpg',
#  'data/obj/18c39c5062b877ee.jpg',
#  'data/obj/18c3a0f0e4a76e68.jpg',
#  'data/obj/18c887f287ccb1c7.jpg',
#  'data/obj/18cb9f64c6744ee0.jpg',
#  'data/obj/18cdd6cbd036db0e.jpg',
#  'data/obj/18d31a8b7a12ec42.jpg',
#  'data/obj/18d43dbbd79aa35c.jpg',
#  'data/obj/18d8c9447683ebae.jpg',
#  'data/obj/18d938f8d67536bd.jpg',
#  'data/obj/18db891fed9d9711.jpg',
#  'data/obj/18de0bcaf0056205.jpg',
#  'data/obj/18df4aaf3851aaf4.jpg',
#  'data/obj/18e07504343f1150.jpg',
#  'data/obj/18e0eb8b2cf2d725.jpg',
#  'data/obj/18e2fdba6aef8a27.jpg',
#  'data/obj/18e862f19c721d18.jpg',
#  'data/obj/18e9482efefaaa12.jpg',
#  'data/obj/18ea3c0161fb370a.jpg',
#  'data/obj/18ece458e7a897d6.jpg',
#  'data/obj/18ee6095c6294cea.jpg',
#  'data/obj/18f074486ec67289.jpg',
#  'data/obj/18f0d209633417bc.jpg',
#  'data/obj/18f1a81096c39e46.jpg',
#  'data/obj/18f4fa0643c0c9f5.jpg',
#  'data/obj/18f8c5d366edcf7c.jpg',
#  'data/obj/18f9f3256eb5d858.jpg',
#  'data/obj/18fcf3a9e11f6754.jpg',
#  'data/obj/18fde901697b1d69.jpg',
#  'data/obj/19019640f92845bc.jpg',
#  'data/obj/19046fa25527f67c.jpg',
#  'data/obj/19072d9736bf4987.jpg',
#  'data/obj/190c21991398e892.jpg',
#  'data/obj/191313ae59905983.jpg',
#  'data/obj/191350b62f5c306a.jpg',
#  'data/obj/19162c1ea43f227f.jpg',
#  'data/obj/1916a0451b72c6d1.jpg',
#  'data/obj/191885e7ea7cb0ee.jpg',
#  'data/obj/191d0372928b2935.jpg',
#  'data/obj/191d784341782c4c.jpg',
#  'data/obj/1920a7ba842ad08c.jpg',
#  'data/obj/192335c2e81b6886.jpg',
#  'data/obj/192622955edfb072.jpg',
#  'data/obj/19288bda627999df.jpg',
#  'data/obj/19297eb60c61331b.jpg',
#  'data/obj/192b2b724c91a183.jpg',
#  'data/obj/192b64607ce60078.jpg',
#  'data/obj/192f504964019fc0.jpg',
#  'data/obj/19310e291ed760b8.jpg',
#  'data/obj/1932b89693dd2af5.jpg',
#  'data/obj/1934e961eca1a61b.jpg',
#  'data/obj/19356e660b35a61f.jpg',
#  'data/obj/1937b341aef7ea83.jpg',
#  'data/obj/1938c6f3adcb5fe6.jpg',
#  'data/obj/193984048181d7d9.jpg',
#  'data/obj/193b87346d2efc59.jpg',
#  'data/obj/193bfadefc0068b9.jpg',
#  'data/obj/193fc4185a1645c4.jpg',
#  'data/obj/193fe6a7b8758e20.jpg',
#  'data/obj/19434b247700e58b.jpg',
#  'data/obj/19437860ed40dc8e.jpg',
#  'data/obj/1943b71b41da1055.jpg',
#  'data/obj/19440130c5ecebca.jpg',
#  'data/obj/19450b3feaccc9e5.jpg',
#  'data/obj/194527fa4a423f3c.jpg',
#  'data/obj/19462cee4ea9a21d.jpg',
#  'data/obj/1947ce26dac0092a.jpg',
#  'data/obj/1948c9ab4fbef345.jpg',
#  'data/obj/194b457bb5f9093b.jpg',
#  'data/obj/194c422fc8745ede.jpg',
#  'data/obj/194dc16533ff3d73.jpg',
#  'data/obj/1950bf1849b5480c.jpg',
#  'data/obj/1950e50424efb6c3.jpg',
#  'data/obj/195286cb719e074f.jpg',
#  'data/obj/1958d43b752efa1b.jpg',
#  'data/obj/1959b90c659bca84.jpg',
#  'data/obj/195dc3c6e46315d7.jpg',
#  'data/obj/196382f38d0a8520.jpg',
#  'data/obj/196401b8107071b4.jpg',
#  'data/obj/1968fbe9450cd202.jpg',
#  'data/obj/196a37b277fd15e6.jpg',
#  'data/obj/196ccf6a422b37af.jpg',
#  'data/obj/196d9d2dc6e70558.jpg',
#  'data/obj/196ff082a7027cc9.jpg',
#  'data/obj/1970a892ed53b111.jpg',
#  'data/obj/1972409a979308b0.jpg',
#  'data/obj/1972cb396c4d2c13.jpg',
#  'data/obj/197607eccb4d5b5a.jpg',
#  'data/obj/19768b869d8656c4.jpg',
#  'data/obj/19771f6da57425bc.jpg',
#  'data/obj/1977ed3684b21128.jpg',
#  'data/obj/197896f1feab8dd5.jpg',
#  'data/obj/197bf1ce63a7733b.jpg',
#  'data/obj/197d4347153f3fe8.jpg',
#  'data/obj/198195adaad6d5ed.jpg',
#  'data/obj/19866e1fc1dd9ca1.jpg',
#  'data/obj/1986a6dbe35a1dfa.jpg',
#  'data/obj/198b90750b9d0241.jpg',
#  'data/obj/198d8779efc63df7.jpg',
#  'data/obj/19917035e7110627.jpg',
#  'data/obj/19931f77f4ba5efd.jpg',
#  'data/obj/1993228ac1044188.jpg',
#  'data/obj/199ae50d4716c262.jpg',
#  'data/obj/199b22cb3cb39506.jpg',
#  'data/obj/199b5b297b4c14c0.jpg',
#  'data/obj/199ef35bc0e91bd0.jpg',
#  'data/obj/19a08ac5be587d35.jpg',
#  'data/obj/19a0c85bd8a97419.jpg',
#  'data/obj/19a0d46dbcfd7ba4.jpg',
#  'data/obj/19a48f372d5aca78.jpg',
#  'data/obj/19a5c97fda598043.jpg',
#  'data/obj/19a603ab6e5919b8.jpg',
#  'data/obj/19a78120b9e7dcfd.jpg',
#  'data/obj/19aa3df97b40b9fd.jpg',
#  'data/obj/19add390ca24d41a.jpg',
#  'data/obj/19b2d898c9720ac5.jpg',
#  'data/obj/19b9f38d1aa98fa2.jpg',
#  'data/obj/19b9f3f04a45b764.jpg',
#  'data/obj/19bb60e7af8146e6.jpg',
#  'data/obj/19bebaa900b6f7da.jpg',
#  'data/obj/19c37672d386b56b.jpg',
#  'data/obj/19c51da338339146.jpg',
#  'data/obj/19c66d7dcdd6a7e5.jpg',
#  'data/obj/19c6b1240cdcbe16.jpg',
#  'data/obj/19cb0735535b85f2.jpg',
#  'data/obj/19cc66da6f02d28d.jpg',
#  'data/obj/19ccb063577c8f58.jpg',
#  'data/obj/19d5a04ccdddb8b8.jpg',
#  'data/obj/19d8beda67f85830.jpg',
#  'data/obj/19dd233021e1b467.jpg',
#  'data/obj/19e3b55b7a177baa.jpg',
#  'data/obj/19e3d85eb9347259.jpg',
#  'data/obj/19e3db80b8e3acf0.jpg',
#  'data/obj/19e66454112f9ebc.jpg',
#  'data/obj/19e72cbce32afc41.jpg',
#  'data/obj/19ea77e3f3f00fe5.jpg',
#  'data/obj/19eacf77def557d6.jpg',
#  'data/obj/19ece1fa666924d0.jpg',
#  'data/obj/19ece7f38002f135.jpg',
#  'data/obj/19ee366a9313fb35.jpg',
#  'data/obj/19ee677b23387a84.jpg',
#  'data/obj/19ef467a703e8113.jpg',
#  'data/obj/19f03f9857ed90e5.jpg',
#  'data/obj/19f058ed216ed997.jpg',
#  'data/obj/19f2f19d7da1010a.jpg',
#  'data/obj/19f3fe7cd86daec7.jpg',
#  'data/obj/19f557f3f95846aa.jpg',
#  'data/obj/19f7633ef4956384.jpg',
#  'data/obj/19f881865d5e5d70.jpg',
#  'data/obj/19fb00ab8c8c5317.jpg',
#  'data/obj/19fcf5ba9abe1a26.jpg',
#  'data/obj/19fec264af087aac.jpg',
#  'data/obj/19ff4f1c6588c221.jpg',
#  'data/obj/1a01377d22c29937.jpg',
#  'data/obj/1a03b7545a80cfba.jpg',
#  'data/obj/1a0603db6c0e14e8.jpg',
#  'data/obj/1a06088a4d788490.jpg',
#  'data/obj/1a063d1507de7328.jpg',
#  'data/obj/1a06dd5c1d2d9946.jpg',
#  'data/obj/1a07a015af4eabbf.jpg',
#  'data/obj/1a0859c96b9263e1.jpg',
#  'data/obj/1a0da67003f42551.jpg',
#  'data/obj/1a0e3208fbdef9cd.jpg',
#  'data/obj/1a0e9a93895d4a77.jpg',
#  'data/obj/1a1287bac17f75cf.jpg',
#  'data/obj/1a130260558703a7.jpg',
#  'data/obj/1a19a8576b30a876.jpg',
#  'data/obj/1a1ac3e070606d49.jpg',
#  'data/obj/1a21d91a9631a949.jpg',
#  'data/obj/1a22d3ff8bcf33be.jpg',
#  'data/obj/1a23b6ebf17ef1eb.jpg',
#  'data/obj/1a2e838e954342e3.jpg',
#  'data/obj/1a2e9e8fada4ca22.jpg',
#  'data/obj/1a30a5dd90339981.jpg',
#  'data/obj/1a345a5001a38b7a.jpg',
#  'data/obj/1a351726a8a8e46d.jpg',
#  'data/obj/1a357e354d1c8cf6.jpg',
#  'data/obj/1a3fe2fd6481e4b3.jpg',
#  'data/obj/1a3ff9d0ddd8274c.jpg',
#  'data/obj/1a453d75dffb1984.jpg',
#  'data/obj/1a459d8b883ae023.jpg',
#  'data/obj/1a466b5ab76610e9.jpg',
#  'data/obj/1a4d9aa701e75ac6.jpg',
#  'data/obj/1a50706c65daab74.jpg',
#  'data/obj/1a53a755fbcb075c.jpg',
#  'data/obj/1a5619e711635aa1.jpg',
#  'data/obj/1a565d1ce6e8a00c.jpg',
#  'data/obj/1a5736600cf5d55f.jpg',
#  'data/obj/1a578c225b56c1d0.jpg',
#  'data/obj/1a586e406d525f36.jpg',
#  'data/obj/1a58f12991db6f61.jpg',
#  'data/obj/1a5941b24ffaa215.jpg',
#  'data/obj/1a598a4c92605728.jpg',
#  'data/obj/1a5beb0dcd2f2a07.jpg',
#  'data/obj/1a5d744c7bdcfccc.jpg',
#  'data/obj/1a61bd0147df4434.jpg',
#  'data/obj/1a680e1470a8c82c.jpg',
#  'data/obj/1a6902f517c7ede3.jpg',
#  'data/obj/1a6aa5ddd9b51de3.jpg',
#  'data/obj/1a6f980e51a0ae12.jpg',
#  'data/obj/1a6fc192fad67aa1.jpg',
#  'data/obj/1a7075186280a57f.jpg',
#  'data/obj/1a733cc7df44c2a1.jpg',
#  'data/obj/1a73713413d01605.jpg',
#  'data/obj/1a74be034f88ef90.jpg',
#  'data/obj/1a76513a2a3036fb.jpg',
#  'data/obj/1a79b58d11387c89.jpg',
#  'data/obj/1a7ad0e4c783cd47.jpg',
#  'data/obj/1a7b4f3892565041.jpg',
#  'data/obj/1a7ba7d0ab2968aa.jpg',
#  'data/obj/1a7d2539e1723ab9.jpg',
#  'data/obj/1a7d92ee947ae1eb.jpg',
#  'data/obj/1a8241d699f7bf10.jpg',
#  'data/obj/1a8527d500510c60.jpg',
#  'data/obj/1a863a2d19f2b837.jpg',
#  'data/obj/1a8721343f8582c9.jpg',
#  'data/obj/1a8a2717d681870b.jpg',
#  'data/obj/1a8d5edcd365c44a.jpg',
#  'data/obj/1a8f2da48400e796.jpg',
#  'data/obj/1a8fe0cd70e1b9fc.jpg',
#  'data/obj/1a90b705e3254718.jpg',
#  'data/obj/1a90bf1f04cbb3c6.jpg',
#  'data/obj/1a92f3b867f039e1.jpg',
#  'data/obj/1a96dc6d0a09729a.jpg',
#  'data/obj/1a9b75e58f7257cd.jpg',
#  'data/obj/1a9ccca2e1f3d850.jpg',
#  'data/obj/1a9e8764c92ff444.jpg',
#  'data/obj/1a9ec69f9834ce86.jpg',
#  'data/obj/1a9fba1a96eb8c8e.jpg',
#  'data/obj/1aa5ea3f629b0885.jpg',
#  'data/obj/1aa68a4f5532aa40.jpg',
#  'data/obj/1aab1bf6f200e2e3.jpg',
#  'data/obj/1aaea79187973749.jpg',
#  'data/obj/1aafd03813feedbd.jpg',
#  'data/obj/1ab3ff59e3c9d4b3.jpg',
#  'data/obj/1ab6de33481db654.jpg',
#  'data/obj/1ab7cbdccab59445.jpg',
#  'data/obj/1abf8a178b10a54a.jpg',
#  'data/obj/1ac09a6a0aca5637.jpg',
#  'data/obj/1ac0fc359786ccdd.jpg',
#  'data/obj/1ac0fcd5fae775ca.jpg',
#  'data/obj/1ac3e034468bcfc1.jpg',
#  'data/obj/1ac862b2b9e84cb8.jpg',
#  'data/obj/1ac95c498aba98ee.jpg',
#  'data/obj/1acc190c339830a9.jpg',
#  'data/obj/1acd28d317e12d2c.jpg',
#  'data/obj/1acdd6b42bbd30d8.jpg',
#  'data/obj/1acdf2e735e2a90c.jpg',
#  'data/obj/1ace80c5e169d8ac.jpg',
#  'data/obj/1ad0e33f08126b85.jpg',
#  'data/obj/1ad10000d698e949.jpg',
#  'data/obj/1ad20d959c4b73fd.jpg',
#  'data/obj/1ad24f5ae21a570c.jpg',
#  'data/obj/1ad2ea6ae4577419.jpg',
#  'data/obj/1ad3a76c20994c9a.jpg',
#  'data/obj/1ad4564a1b66de26.jpg',
#  'data/obj/1ad6cb6661be9f67.jpg',
#  'data/obj/1ad88f139a25ee28.jpg',
#  'data/obj/1ad94349ce2a79be.jpg',
#  'data/obj/1adb594a996afd40.jpg',
#  'data/obj/1adc21eb3ca5bf68.jpg',
#  'data/obj/1adc2e54912c3a34.jpg',
#  'data/obj/1add95bfa77fce66.jpg',
#  'data/obj/1adef73d0b0c3267.jpg',
#  'data/obj/1ae0e29e6916cb48.jpg',
#  'data/obj/1ae2353880f0d4cb.jpg',
#  'data/obj/1ae23ff075a366bc.jpg',
#  'data/obj/1ae33b0ec3b806b6.jpg',
#  'data/obj/1ae3eaae16edd9d9.jpg',
#  'data/obj/1ae9d3242ff10b6b.jpg',
#  'data/obj/1aecb8d5f2f5f4e9.jpg',
#  'data/obj/1aecfd473d6a19b3.jpg',
#  'data/obj/1aef4970fa05516d.jpg',
#  'data/obj/1af06a6d622d2a7b.jpg',
#  'data/obj/1af0f34299c544ac.jpg',
#  'data/obj/1af22a2f12440f66.jpg',
#  'data/obj/1af3e2aa286e2317.jpg',
#  'data/obj/1af3f8241ec887ca.jpg',
#  'data/obj/1af4f2000777d06d.jpg',
#  'data/obj/1af7dc0216f7f4d6.jpg',
#  'data/obj/1af836c3cdaeb25c.jpg',
#  'data/obj/1afb9f2693e6c0ef.jpg',
#  'data/obj/1afbcc9116f02fc3.jpg',
#  'data/obj/1b01ca2fd766d047.jpg',
#  'data/obj/1b06f061a5939274.jpg',
#  'data/obj/1b0afc68666da510.jpg',
#  'data/obj/1b0b9fa38720c35e.jpg',
#  'data/obj/1b0e317ff429f413.jpg',
#  'data/obj/1b147c6d1ac045d9.jpg',
#  'data/obj/1b1863b692987427.jpg',
#  'data/obj/1b1a52fb6a9c87e0.jpg',
#  'data/obj/1b1a917f9e7baec5.jpg',
#  'data/obj/1b1c0bb8dbbc0c61.jpg',
#  'data/obj/1b1d52eb70dd4e6e.jpg',
#  'data/obj/1b1ed4f0e1c6aa88.jpg',
#  'data/obj/1b2009fa2f1105e1.jpg',
#  'data/obj/1b20799f0c1c0ee9.jpg',
#  'data/obj/1b22bc73aa5db797.jpg',
#  'data/obj/1b23464aa083bbc6.jpg',
#  'data/obj/1b236681948723e0.jpg',
#  'data/obj/1b244a1f1e1c972c.jpg',
#  'data/obj/1b274fd4d5136dfc.jpg',
#  'data/obj/1b29d77e81932528.jpg',
#  'data/obj/1b2f193e9ff41c77.jpg',
#  ...]
